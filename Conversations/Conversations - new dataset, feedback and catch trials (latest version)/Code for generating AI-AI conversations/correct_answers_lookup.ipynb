# %%
import pandas as pd
import json

# Configuration
excel_file = "esChat.xlsx"  # Path to your Excel file
output_json = "correct_answers.json"  # Output JSON file
length_list = [3, 6, 9, 12, 15, 18, 21, 24]  # All required snippet lengths

# Read the Excel file
try:
    df = pd.read_excel(excel_file)
    print(f"Successfully loaded Excel file with {len(df)} rows")
    
    # Show column names for debugging
    print(f"\nColumn names:")
    for i, col in enumerate(df.columns):
        print(f"  {i}: '{col}'")
    
except Exception as e:
    print(f"Error loading Excel file: {e}")
    exit(1)

# Filter for mcq == 12 (not 24)
filtered_df = df[df['mcq'] == 12]
print(f"\nFiltered to {len(filtered_df)} rows where mcq == 12")

if len(filtered_df) == 0:
    print("No rows found with mcq == 12. Please check your data.")
    exit(1)

# Check required columns exist
required_columns = ['conversation_id', 'A_label', 'B_label']
missing_columns = [col for col in required_columns if col not in df.columns]

if missing_columns:
    print(f"\nERROR: Missing required columns: {missing_columns}")
    print("Available columns:", list(df.columns))
    exit(1)

# Function to convert label to code
def label_to_code(label):
    if pd.isna(label):
        return "?"
    label_str = str(label).strip().lower()
    if 'human' in label_str:
        return 'H'
    elif 'ai' in label_str:
        return 'AI'
    else:
        return label_str.upper()  # Return as-is if not human/ai

# Generate the correct answers dictionary
correct_answers = {}

for _, row in filtered_df.iterrows():
    conv_id = int(row['conversation_id'])
    a_label = label_to_code(row['A_label'])
    b_label = label_to_code(row['B_label'])
    
    # Combine A and B labels
    combined_label = a_label + b_label
    
    print(f"Conversation {conv_id}: A={row['A_label']} -> {a_label}, B={row['B_label']} -> {b_label} = {combined_label}")
    
    # Add entries for all lengths
    for length in length_list:
        key = f"conv{conv_id}_len{length}"
        correct_answers[key] = combined_label

# Sort the dictionary by key for better readability
correct_answers = dict(sorted(correct_answers.items()))

# Save to JSON file
with open(output_json, 'w') as f:
    json.dump(correct_answers, f, indent=2)

print(f"\nGenerated {len(correct_answers)} entries")
print(f"Saved to {output_json}")

# Show a sample of the output
print(f"\nSample entries:")
for i, (key, value) in enumerate(correct_answers.items()):
    if i < 10:  # Show first 10 entries
        print(f'  "{key}": "{value}"')
    elif i == 10:
        print("  ...")
        break

print(f"\nEntries per conversation: {len(length_list)}")
print(f"Total conversations processed: {len(filtered_df)}")

# Summary of label combinations
label_summary = {}
for value in correct_answers.values():
    label_summary[value] = label_summary.get(value, 0) + 1

print(f"\nLabel combinations found:")
for label, count in sorted(label_summary.items()):
    print(f"  {label}: {count} entries")
# Out:
# Successfully loaded Excel file with 210 rows
#
# Column names:
#   0: 'conversation_id'
#   1: 'Conv_label'
#   2: 'mcq'
#   3: 'A_label'
#   4: 'A_age'
#   5: 'A_gender'
#   6: 'B_label'
#   7: 'B_age'
#   8: 'B_gender'
#   9: 'A_judgeByB'
#   10: 'A_age_judgeByB'
#   11: 'A_gender_judgeByB'
#   12: 'B_judgeByA'
#   13: 'B_age_judgeByA'
#   14: 'B_gender_judgebyA'
#   15: 'topic'
#   16: 'topic_label'
#
# Filtered to 175 rows where mcq == 12
# Conversation 35: A=Human -> H, B=Human -> H = HH
# Conversation 46: A=Human -> H, B=Human -> H = HH
# Conversation 57: A=Human -> H, B=AI -> AI = HAI
# Conversation 58: A=Human -> H, B=Human -> H = HH
# Conversation 60: A=AI -> AI, B=Human -> H = AIH
# Conversation 61: A=Human -> H, B=Human -> H = HH
# Conversation 62: A=Human -> H, B=Human -> H = HH
# Conversation 63: A=Human -> H, B=Human -> H = HH
# Conversation 65: A=AI -> AI, B=Human -> H = AIH
# Conversation 67: A=AI -> AI, B=Human -> H = AIH
# Conversation 68: A=AI -> AI, B=Human -> H = AIH
# Conversation 69: A=AI -> AI, B=Human -> H = AIH
# Conversation 70: A=Human -> H, B=AI -> AI = HAI
# Conversation 73: A=AI -> AI, B=Human -> H = AIH
# Conversation 75: A=Human -> H, B=Human -> H = HH
# Conversation 76: A=Human -> H, B=AI -> AI = HAI
# Conversation 79: A=Human -> H, B=AI -> AI = HAI
# Conversation 80: A=AI -> AI, B=Human -> H = AIH
# Conversation 81: A=Human -> H, B=AI -> AI = HAI
# Conversation 82: A=Human -> H, B=AI -> AI = HAI
# Conversation 83: A=AI -> AI, B=Human -> H = AIH
# Conversation 84: A=Human -> H, B=AI -> AI = HAI
# Conversation 85: A=AI -> AI, B=Human -> H = AIH
# Conversation 86: A=Human -> H, B=AI -> AI = HAI
# Conversation 87: A=AI -> AI, B=Human -> H = AIH
# Conversation 88: A=AI -> AI, B=Human -> H = AIH
# Conversation 89: A=AI -> AI, B=Human -> H = AIH
# Conversation 90: A=AI -> AI, B=Human -> H = AIH
# Conversation 91: A=Human -> H, B=AI -> AI = HAI
# Conversation 93: A=AI -> AI, B=Human -> H = AIH
# Conversation 94: A=Human -> H, B=AI -> AI = HAI
# Conversation 95: A=Human -> H, B=AI -> AI = HAI
# Conversation 96: A=Human -> H, B=Human -> H = HH
# Conversation 97: A=Human -> H, B=AI -> AI = HAI
# Conversation 98: A=Human -> H, B=AI -> AI = HAI
# Conversation 99: A=Human -> H, B=AI -> AI = HAI
# Conversation 100: A=Human -> H, B=AI -> AI = HAI
# Conversation 101: A=AI -> AI, B=Human -> H = AIH
# Conversation 103: A=Human -> H, B=AI -> AI = HAI
# Conversation 104: A=AI -> AI, B=Human -> H = AIH
# Conversation 105: A=Human -> H, B=AI -> AI = HAI
# Conversation 106: A=Human -> H, B=AI -> AI = HAI
# Conversation 107: A=Human -> H, B=AI -> AI = HAI
# Conversation 109: A=Human -> H, B=AI -> AI = HAI
# Conversation 110: A=Human -> H, B=AI -> AI = HAI
# Conversation 111: A=AI -> AI, B=Human -> H = AIH
# Conversation 113: A=AI -> AI, B=Human -> H = AIH
# Conversation 114: A=Human -> H, B=AI -> AI = HAI
# Conversation 115: A=Human -> H, B=AI -> AI = HAI
# Conversation 116: A=Human -> H, B=AI -> AI = HAI
# Conversation 117: A=Human -> H, B=AI -> AI = HAI
# Conversation 118: A=AI -> AI, B=Human -> H = AIH
# Conversation 120: A=Human -> H, B=AI -> AI = HAI
# Conversation 121: A=AI -> AI, B=Human -> H = AIH
# Conversation 122: A=AI -> AI, B=Human -> H = AIH
# Conversation 123: A=AI -> AI, B=Human -> H = AIH
# Conversation 124: A=Human -> H, B=AI -> AI = HAI
# Conversation 126: A=Human -> H, B=Human -> H = HH
# Conversation 127: A=Human -> H, B=Human -> H = HH
# Conversation 129: A=Human -> H, B=Human -> H = HH
# Conversation 130: A=Human -> H, B=Human -> H = HH
# Conversation 131: A=Human -> H, B=Human -> H = HH
# Conversation 132: A=Human -> H, B=Human -> H = HH
# Conversation 133: A=Human -> H, B=Human -> H = HH
# Conversation 134: A=Human -> H, B=Human -> H = HH
# Conversation 136: A=Human -> H, B=Human -> H = HH
# Conversation 135: A=Human -> H, B=Human -> H = HH
# Conversation 137: A=Human -> H, B=Human -> H = HH
# Conversation 138: A=Human -> H, B=Human -> H = HH
# Conversation 142: A=Human -> H, B=Human -> H = HH
# Conversation 139: A=Human -> H, B=Human -> H = HH
# Conversation 146: A=Human -> H, B=Human -> H = HH
# Conversation 149: A=AI -> AI, B=Human -> H = AIH
# Conversation 150: A=AI -> AI, B=Human -> H = AIH
# Conversation 154: A=Human -> H, B=Human -> H = HH
# Conversation 155: A=Human -> H, B=Human -> H = HH
# Conversation 156: A=Human -> H, B=Human -> H = HH
# Conversation 158: A=Human -> H, B=Human -> H = HH
# Conversation 159: A=Human -> H, B=Human -> H = HH
# Conversation 162: A=Human -> H, B=Human -> H = HH
# Conversation 164: A=Human -> H, B=Human -> H = HH
# Conversation 171: A=Human -> H, B=Human -> H = HH
# Conversation 174: A=Human -> H, B=Human -> H = HH
# Conversation 175: A=Human -> H, B=Human -> H = HH
# Conversation 176: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 177: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 178: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 179: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 180: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 181: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 182: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 183: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 184: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 185: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 186: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 187: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 188: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 189: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 190: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 191: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 192: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 193: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 194: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 195: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 196: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 197: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 198: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 199: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 200: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 201: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 202: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 203: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 204: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 205: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 206: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 207: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 208: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 209: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 210: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 211: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 212: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 213: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 214: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 215: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 216: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 217: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 218: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 219: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 220: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 221: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 222: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 223: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 224: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 225: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 226: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 227: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 228: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 229: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 230: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 231: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 232: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 233: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 234: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 235: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 236: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 237: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 238: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 239: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 240: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 241: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 242: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 243: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 244: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 245: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 246: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 247: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 248: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 249: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 250: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 251: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 252: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 253: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 254: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 255: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 256: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 257: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 258: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 259: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 260: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 261: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 262: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 263: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 264: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 265: A=AI -> AI, B=AI -> AI = AIAI
# Conversation 266: A=AI -> AI, B=AI -> AI = AIAI
#
# Generated 1400 entries
# Saved to correct_answers.json
#
# Sample entries:
#   "conv100_len12": "HAI"
#   "conv100_len15": "HAI"
#   "conv100_len18": "HAI"
#   "conv100_len21": "HAI"
#   "conv100_len24": "HAI"
#   "conv100_len3": "HAI"
#   "conv100_len6": "HAI"
#   "conv100_len9": "HAI"
#   "conv101_len12": "AIH"
#   "conv101_len15": "AIH"
#   ...
#
# Entries per conversation: 8
# Total conversations processed: 175
#
# Label combinations found:
#   AIAI: 728 entries
#   AIH: 192 entries
#   HAI: 216 entries
#   HH: 264 entries
