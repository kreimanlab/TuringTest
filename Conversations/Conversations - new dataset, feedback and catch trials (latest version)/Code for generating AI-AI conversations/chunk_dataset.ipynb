# %%
import linecache
import os
import glob
import pandas as pd
import random

# Configuration
source_folder = "/Users/elisapavarino/Documents/Work_Directory/Kreiman_Lab/Turing Test Paper/TuringGithub/conversation/conversation_task_for_revisions/new_dataset"  # CHANGE THIS: Path to folder containing conv*.html files
excel_file = "esChat.xlsx"  # Path to your Excel file
output_folder = "dataset"  # Output folder name
length_list = [3, 6, 9, 12, 15, 18, 21, 24]  # All required snippet lengths

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Read the Excel file
try:
    df = pd.read_excel(excel_file)
    print(f"Successfully loaded Excel file with {len(df)} rows")
    
    # Debug: Show DataFrame info
    print(f"\nDataFrame shape: {df.shape}")
    print(f"\nColumn names:")
    for i, col in enumerate(df.columns):
        print(f"  {i}: '{col}'")
    
    print(f"\nFirst few rows:")
    print(df.head())
    
    # Check if the expected columns exist
    required_columns = ['conversation_id', 'topic', 'topic_label']
    missing_columns = [col for col in required_columns if col not in df.columns]
    
    if missing_columns:
        print(f"\nERROR: Missing required columns: {missing_columns}")
        print("Please check your Excel file column names.")
        exit(1)
    
except Exception as e:
    print(f"Error loading Excel file: {e}")
    exit(1)

# Get all unique topics (excluding the correct one for each conversation)
all_topics = df['topic'].unique().tolist()
print(f"Found {len(all_topics)} unique topics: {all_topics}")

# Find all conversation files in the source folder
conv_files = glob.glob(os.path.join(source_folder, "conv*.html"))
conv_numbers = []

# Extract conversation numbers from filenames
for file in conv_files:
    filename = os.path.basename(file)
    if filename.startswith("conv") and filename.endswith(".html"):
        try:
            # Extract number from filename like "conv123.html"
            num_str = filename[4:-5]  # Remove "conv" and ".html"
            if num_str.isdigit():
                conv_numbers.append(int(num_str))
        except:
            continue

# Sort conversation numbers
conv_numbers.sort()
print(f"Found conversation files: {conv_numbers}")

# Process each conversation
processed_count = 0
for conv_num in conv_numbers:
    # Find this conversation in the Excel file
    conv_row = df[df['conversation_id'] == conv_num]
    
    if conv_row.empty:
        print(f"Warning: Conversation {conv_num} not found in Excel file, skipping...")
        continue
    
    conv_data = conv_row.iloc[0]
    correct_topic = conv_data['topic']
    topic_label = int(conv_data['topic_label'])  # Which position (1-5) the correct topic should be in
    
    print(f"\nProcessing conversation {conv_num}")
    print(f"  Correct topic: '{correct_topic}' (will be in position {topic_label})")
    
    original_file = os.path.join(source_folder, f'conv{conv_num}.html')
    
    # Check if original conversation file exists
    if not os.path.exists(original_file):
        print(f"Warning: {original_file} not found, skipping...")
        continue
    
    # Generate 4 other topics (excluding the correct one)
    other_topics = [topic for topic in all_topics if topic != correct_topic]
    random.shuffle(other_topics)
    selected_other_topics = other_topics[:4]  # Take first 4 after shuffle
    
    # Create the 5 topics list with correct topic in the right position
    topics_list = [None] * 5
    topics_list[topic_label - 1] = correct_topic  # topic_label is 1-based
    
    # Fill the remaining positions with the other topics
    other_index = 0
    for i in range(5):
        if topics_list[i] is None:
            topics_list[i] = selected_other_topics[other_index]
            other_index += 1
    
    print(f"  Topic options: {topics_list}")
    
    # Create snippets for each length
    for length in length_list:
        # Create main snippet file
        snippet_filename = os.path.join(output_folder, f'conv{conv_num}_len{length}.html')
        
        with open(snippet_filename, "w", encoding='utf-8') as file_html:
            # Write the conversation snippet
            for line in range(1, length + 1):
                particular_line = linecache.getline(original_file, line)
                if particular_line.strip():  # Only write non-empty lines
                    file_html.write(particular_line)
        
        # Create 5 option files with the topics
        for option_num in range(1, 6):
            option_filename = os.path.join(output_folder, f'conv{conv_num}_len{length}option{option_num}.html')
            
            with open(option_filename, "w", encoding='utf-8') as option_file:
                option_file.write(topics_list[option_num - 1])
    
    processed_count += 1

print(f"\nProcessing complete!")
print(f"Successfully processed {processed_count} conversations")
print(f"All files created in '{output_folder}' folder")
print("Files created:")
print("- Conversation snippets: conv*_len*.html")
print("- Topic options: conv*_len*option*.html")

# Clear linecache to free memory
linecache.clearcache()
# Out:
# Successfully loaded Excel file with 210 rows
#
# DataFrame shape: (210, 17)
#
# Column names:
#   0: 'conversation_id'
#   1: 'Conv_label'
#   2: 'mcq'
#   3: 'A_label'
#   4: 'A_age'
#   5: 'A_gender'
#   6: 'B_label'
#   7: 'B_age'
#   8: 'B_gender'
#   9: 'A_judgeByB'
#   10: 'A_age_judgeByB'
#   11: 'A_gender_judgeByB'
#   12: 'B_judgeByA'
#   13: 'B_age_judgeByA'
#   14: 'B_gender_judgebyA'
#   15: 'topic'
#   16: 'topic_label'
#
# First few rows:
#    conversation_id           Conv_label  mcq A_label              A_age  \
# 0               34         GPT-4o-Human   24      AI  26 - 30 years old
# 1               35          Human-Human   12   Human  31 - 35 years old
# 2               46          Human-Human   12   Human  21 - 25 years old
# 3               55         GPT-4o-Human   24      AI  31 - 35 years old
# 4               57  Human-Llama-3.3-70B   12   Human  26 - 30 years old
#
#   A_gender B_label               B_age B_gender A_judgeByB     A_age_judgeByB  \
# 0   Female   Human   26 - 30 years old     Male         AI  31 - 35 years old
# 1   Female   Human  above 50 years old     Male      Human  26 - 30 years old
# 2     Male   Human   31 - 35 years old   Female        NaN                NaN
# 3   Female   Human   26 - 30 years old   Female         AI  31 - 35 years old
# 4   Female      AI   18 - 20 years old     Male        NaN                NaN
#
#   A_gender_judgeByB B_judgeByA     B_age_judgeByA B_gender_judgebyA     topic  \
# 0              Male        NaN                NaN               NaN    sports
# 1            Female      Human  46 - 50 years old              Male   science
# 2               NaN        NaN                NaN               NaN  politics
# 3            Female        NaN                NaN               NaN    movies
# 4               NaN      Human  21 - 25 years old              Male   fashion
#
#    topic_label
# 0            5
# 1            5
# 2            5
# 3            5
# 4            5
# Found 14 unique topics: ['sports', 'science', 'politics', 'movies', 'fashion', 'music', 'general_entertainment', 'books', 'food', 'technology', 'quarrel', 'traffic', 'emotions', 'ageing']
# Found conversation files: [35, 46, 57, 58, 60, 61, 62, 63, 65, 67, 68, 69, 70, 73, 75, 76, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 93, 94, 95, 96, 97, 98, 99, 100, 101, 103, 104, 105, 106, 107, 109, 110, 111, 113, 114, 115, 116, 117, 118, 120, 121, 122, 123, 124, 126, 127, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 142, 146, 149, 150, 154, 155, 156, 158, 159, 160, 162, 164, 171, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266]
#
# Processing conversation 35
#   Correct topic: 'science' (will be in position 5)
#   Topic options: ['ageing', 'food', 'fashion', 'sports', 'science']
#
# Processing conversation 46
#   Correct topic: 'politics' (will be in position 5)
#   Topic options: ['food', 'traffic', 'ageing', 'fashion', 'politics']
#
# Processing conversation 57
#   Correct topic: 'fashion' (will be in position 5)
#   Topic options: ['emotions', 'science', 'general_entertainment', 'politics', 'fashion']
#
# Processing conversation 58
#   Correct topic: 'music' (will be in position 5)
#   Topic options: ['technology', 'quarrel', 'politics', 'general_entertainment', 'music']
#
# Processing conversation 60
#   Correct topic: 'politics' (will be in position 5)
#   Topic options: ['technology', 'fashion', 'movies', 'sports', 'politics']
#
# Processing conversation 61
#   Correct topic: 'politics' (will be in position 5)
#   Topic options: ['general_entertainment', 'fashion', 'traffic', 'movies', 'politics']
#
# Processing conversation 62
#   Correct topic: 'general_entertainment' (will be in position 5)
#   Topic options: ['politics', 'sports', 'quarrel', 'books', 'general_entertainment']
#
# Processing conversation 63
#   Correct topic: 'science' (will be in position 5)
#   Topic options: ['quarrel', 'traffic', 'ageing', 'politics', 'science']
#
# Processing conversation 65
#   Correct topic: 'music' (will be in position 1)
#   Topic options: ['music', 'movies', 'food', 'quarrel', 'traffic']
#
# Processing conversation 67
#   Correct topic: 'fashion' (will be in position 1)
#   Topic options: ['fashion', 'music', 'sports', 'food', 'emotions']
#
# Processing conversation 68
#   Correct topic: 'fashion' (will be in position 1)
#   Topic options: ['fashion', 'food', 'books', 'politics', 'movies']
#
# Processing conversation 69
#   Correct topic: 'music' (will be in position 1)
#   Topic options: ['music', 'emotions', 'technology', 'sports', 'quarrel']
#
# Processing conversation 70
#   Correct topic: 'fashion' (will be in position 1)
#   Topic options: ['fashion', 'ageing', 'science', 'movies', 'politics']
#
# Processing conversation 73
#   Correct topic: 'sports' (will be in position 1)
#   Topic options: ['sports', 'politics', 'music', 'food', 'books']
#
# Processing conversation 75
#   Correct topic: 'books' (will be in position 1)
#   Topic options: ['books', 'politics', 'traffic', 'emotions', 'quarrel']
#
# Processing conversation 76
#   Correct topic: 'sports' (will be in position 1)
#   Topic options: ['sports', 'movies', 'politics', 'science', 'emotions']
#
# Processing conversation 79
#   Correct topic: 'politics' (will be in position 1)
#   Topic options: ['politics', 'quarrel', 'music', 'science', 'technology']
#
# Processing conversation 80
#   Correct topic: 'food' (will be in position 1)
#   Topic options: ['food', 'general_entertainment', 'ageing', 'politics', 'quarrel']
#
# Processing conversation 81
#   Correct topic: 'movies' (will be in position 1)
#   Topic options: ['movies', 'fashion', 'general_entertainment', 'ageing', 'politics']
#
# Processing conversation 82
#   Correct topic: 'politics' (will be in position 1)
#   Topic options: ['politics', 'food', 'sports', 'emotions', 'general_entertainment']
#
# Processing conversation 83
#   Correct topic: 'politics' (will be in position 1)
#   Topic options: ['politics', 'sports', 'food', 'technology', 'ageing']
#
# Processing conversation 84
#   Correct topic: 'music' (will be in position 1)
#   Topic options: ['music', 'fashion', 'ageing', 'general_entertainment', 'movies']
#
# Processing conversation 85
#   Correct topic: 'science' (will be in position 1)
#   Topic options: ['science', 'sports', 'fashion', 'music', 'general_entertainment']
#
# Processing conversation 86
#   Correct topic: 'music' (will be in position 1)
#   Topic options: ['music', 'science', 'ageing', 'movies', 'fashion']
#
# Processing conversation 87
#   Correct topic: 'books' (will be in position 1)
#   Topic options: ['books', 'emotions', 'general_entertainment', 'technology', 'music']
#
# Processing conversation 88
#   Correct topic: 'science' (will be in position 1)
#   Topic options: ['science', 'emotions', 'ageing', 'traffic', 'movies']
#
# Processing conversation 89
#   Correct topic: 'technology' (will be in position 1)
#   Topic options: ['technology', 'books', 'traffic', 'emotions', 'fashion']
#
# Processing conversation 90
#   Correct topic: 'technology' (will be in position 1)
#   Topic options: ['technology', 'quarrel', 'emotions', 'sports', 'music']
#
# Processing conversation 91
#   Correct topic: 'politics' (will be in position 1)
#   Topic options: ['politics', 'books', 'sports', 'movies', 'traffic']
#
# Processing conversation 93
#   Correct topic: 'books' (will be in position 1)
#   Topic options: ['books', 'traffic', 'general_entertainment', 'emotions', 'food']
#
# Processing conversation 94
#   Correct topic: 'music' (will be in position 1)
#   Topic options: ['music', 'ageing', 'books', 'food', 'movies']
#
# Processing conversation 95
#   Correct topic: 'science' (will be in position 1)
#   Topic options: ['science', 'emotions', 'books', 'ageing', 'sports']
#
# Processing conversation 96
#   Correct topic: 'books' (will be in position 1)
#   Topic options: ['books', 'sports', 'ageing', 'technology', 'science']
#
# Processing conversation 97
#   Correct topic: 'food' (will be in position 1)
#   Topic options: ['food', 'science', 'books', 'emotions', 'fashion']
#
# Processing conversation 98
#   Correct topic: 'food' (will be in position 1)
#   Topic options: ['food', 'ageing', 'fashion', 'music', 'traffic']
#
# Processing conversation 99
#   Correct topic: 'science' (will be in position 1)
#   Topic options: ['science', 'movies', 'ageing', 'technology', 'quarrel']
#
# Processing conversation 100
#   Correct topic: 'books' (will be in position 1)
#   Topic options: ['books', 'general_entertainment', 'movies', 'politics', 'fashion']
#
# Processing conversation 101
#   Correct topic: 'fashion' (will be in position 1)
#   Topic options: ['fashion', 'politics', 'sports', 'ageing', 'traffic']
#
# Processing conversation 103
#   Correct topic: 'movies' (will be in position 1)
#   Topic options: ['movies', 'sports', 'food', 'emotions', 'books']
#
# Processing conversation 104
#   Correct topic: 'technology' (will be in position 1)
#   Topic options: ['technology', 'food', 'traffic', 'quarrel', 'politics']
#
# Processing conversation 105
#   Correct topic: 'food' (will be in position 1)
#   Topic options: ['food', 'general_entertainment', 'politics', 'technology', 'emotions']
#
# Processing conversation 106
#   Correct topic: 'politics' (will be in position 1)
#   Topic options: ['politics', 'movies', 'sports', 'music', 'food']
#
# Processing conversation 107
#   Correct topic: 'food' (will be in position 1)
#   Topic options: ['food', 'sports', 'emotions', 'fashion', 'books']
#
# Processing conversation 109
#   Correct topic: 'general_entertainment' (will be in position 1)
#   Topic options: ['general_entertainment', 'sports', 'science', 'movies', 'books']
#
# Processing conversation 110
#   Correct topic: 'technology' (will be in position 2)
#   Topic options: ['politics', 'technology', 'science', 'sports', 'fashion']
#
# Processing conversation 111
#   Correct topic: 'politics' (will be in position 2)
#   Topic options: ['general_entertainment', 'politics', 'traffic', 'ageing', 'technology']
#
# Processing conversation 113
#   Correct topic: 'science' (will be in position 2)
#   Topic options: ['traffic', 'science', 'food', 'politics', 'books']
#
# Processing conversation 114
#   Correct topic: 'food' (will be in position 2)
#   Topic options: ['fashion', 'food', 'quarrel', 'ageing', 'technology']
#
# Processing conversation 115
#   Correct topic: 'politics' (will be in position 2)
#   Topic options: ['sports', 'politics', 'quarrel', 'food', 'movies']
#
# Processing conversation 116
#   Correct topic: 'science' (will be in position 2)
#   Topic options: ['technology', 'science', 'politics', 'general_entertainment', 'sports']
#
# Processing conversation 117
#   Correct topic: 'technology' (will be in position 2)
#   Topic options: ['general_entertainment', 'technology', 'science', 'sports', 'politics']
#
# Processing conversation 118
#   Correct topic: 'food' (will be in position 2)
#   Topic options: ['traffic', 'food', 'fashion', 'ageing', 'technology']
#
# Processing conversation 120
#   Correct topic: 'books' (will be in position 2)
#   Topic options: ['movies', 'books', 'food', 'quarrel', 'ageing']
#
# Processing conversation 121
#   Correct topic: 'politics' (will be in position 2)
#   Topic options: ['traffic', 'politics', 'general_entertainment', 'food', 'emotions']
#
# Processing conversation 122
#   Correct topic: 'general_entertainment' (will be in position 2)
#   Topic options: ['movies', 'general_entertainment', 'fashion', 'traffic', 'food']
#
# Processing conversation 123
#   Correct topic: 'food' (will be in position 2)
#   Topic options: ['traffic', 'food', 'books', 'fashion', 'movies']
#
# Processing conversation 124
#   Correct topic: 'movies' (will be in position 2)
#   Topic options: ['general_entertainment', 'movies', 'ageing', 'fashion', 'sports']
#
# Processing conversation 126
#   Correct topic: 'general_entertainment' (will be in position 2)
#   Topic options: ['emotions', 'general_entertainment', 'movies', 'music', 'fashion']
#
# Processing conversation 127
#   Correct topic: 'politics' (will be in position 2)
#   Topic options: ['music', 'politics', 'sports', 'books', 'traffic']
#
# Processing conversation 129
#   Correct topic: 'fashion' (will be in position 2)
#   Topic options: ['science', 'fashion', 'food', 'ageing', 'traffic']
#
# Processing conversation 130
#   Correct topic: 'fashion' (will be in position 2)
#   Topic options: ['books', 'fashion', 'movies', 'ageing', 'sports']
#
# Processing conversation 131
#   Correct topic: 'sports' (will be in position 2)
#   Topic options: ['ageing', 'sports', 'technology', 'books', 'politics']
#
# Processing conversation 132
#   Correct topic: 'books' (will be in position 2)
#   Topic options: ['fashion', 'books', 'quarrel', 'technology', 'politics']
#
# Processing conversation 133
#   Correct topic: 'fashion' (will be in position 2)
#   Topic options: ['books', 'fashion', 'politics', 'general_entertainment', 'emotions']
#
# Processing conversation 134
#   Correct topic: 'science' (will be in position 2)
#   Topic options: ['music', 'science', 'general_entertainment', 'books', 'emotions']
#
# Processing conversation 135
#   Correct topic: 'music' (will be in position 2)
#   Topic options: ['ageing', 'music', 'books', 'science', 'food']
#
# Processing conversation 136
#   Correct topic: 'food' (will be in position 2)
#   Topic options: ['books', 'food', 'emotions', 'science', 'technology']
#
# Processing conversation 137
#   Correct topic: 'science' (will be in position 2)
#   Topic options: ['movies', 'science', 'politics', 'quarrel', 'general_entertainment']
#
# Processing conversation 138
#   Correct topic: 'food' (will be in position 2)
#   Topic options: ['books', 'food', 'politics', 'quarrel', 'technology']
#
# Processing conversation 139
#   Correct topic: 'technology' (will be in position 2)
#   Topic options: ['movies', 'technology', 'fashion', 'books', 'quarrel']
#
# Processing conversation 142
#   Correct topic: 'science' (will be in position 2)
#   Topic options: ['emotions', 'science', 'technology', 'food', 'sports']
#
# Processing conversation 146
#   Correct topic: 'science' (will be in position 2)
#   Topic options: ['quarrel', 'science', 'music', 'fashion', 'emotions']
#
# Processing conversation 149
#   Correct topic: 'food' (will be in position 2)
#   Topic options: ['traffic', 'food', 'politics', 'general_entertainment', 'emotions']
#
# Processing conversation 150
#   Correct topic: 'fashion' (will be in position 2)
#   Topic options: ['ageing', 'fashion', 'sports', 'general_entertainment', 'traffic']
#
# Processing conversation 154
#   Correct topic: 'music' (will be in position 2)
#   Topic options: ['politics', 'music', 'traffic', 'sports', 'fashion']
#
# Processing conversation 155
#   Correct topic: 'fashion' (will be in position 2)
#   Topic options: ['quarrel', 'fashion', 'traffic', 'movies', 'sports']
#
# Processing conversation 156
#   Correct topic: 'sports' (will be in position 2)
#   Topic options: ['politics', 'sports', 'books', 'ageing', 'traffic']
#
# Processing conversation 158
#   Correct topic: 'music' (will be in position 2)
#   Topic options: ['sports', 'music', 'books', 'traffic', 'general_entertainment']
#
# Processing conversation 159
#   Correct topic: 'politics' (will be in position 2)
#   Topic options: ['food', 'politics', 'emotions', 'fashion', 'ageing']
#
# Processing conversation 160
#   Correct topic: 'science' (will be in position 2)
#   Topic options: ['fashion', 'science', 'technology', 'ageing', 'music']
#
# Processing conversation 162
#   Correct topic: 'politics' (will be in position 2)
#   Topic options: ['ageing', 'politics', 'science', 'quarrel', 'general_entertainment']
#
# Processing conversation 164
#   Correct topic: 'music' (will be in position 2)
#   Topic options: ['movies', 'music', 'food', 'sports', 'general_entertainment']
#
# Processing conversation 171
#   Correct topic: 'music' (will be in position 2)
#   Topic options: ['general_entertainment', 'music', 'politics', 'books', 'traffic']
#
# Processing conversation 174
#   Correct topic: 'sports' (will be in position 3)
#   Topic options: ['politics', 'quarrel', 'sports', 'emotions', 'technology']
#
# Processing conversation 175
#   Correct topic: 'food' (will be in position 3)
#   Topic options: ['movies', 'quarrel', 'food', 'fashion', 'books']
#
# Processing conversation 176
#   Correct topic: 'technology' (will be in position 3)
#   Topic options: ['music', 'ageing', 'technology', 'movies', 'fashion']
#
# Processing conversation 177
#   Correct topic: 'music' (will be in position 3)
#   Topic options: ['emotions', 'movies', 'music', 'books', 'food']
#
# Processing conversation 178
#   Correct topic: 'movies' (will be in position 3)
#   Topic options: ['science', 'politics', 'movies', 'traffic', 'books']
#
# Processing conversation 179
#   Correct topic: 'fashion' (will be in position 3)
#   Topic options: ['general_entertainment', 'technology', 'fashion', 'food', 'traffic']
#
# Processing conversation 180
#   Correct topic: 'food' (will be in position 3)
#   Topic options: ['science', 'general_entertainment', 'food', 'books', 'movies']
#
# Processing conversation 181
#   Correct topic: 'fashion' (will be in position 3)
#   Topic options: ['food', 'traffic', 'fashion', 'technology', 'science']
#
# Processing conversation 182
#   Correct topic: 'music' (will be in position 3)
#   Topic options: ['movies', 'politics', 'music', 'books', 'science']
#
# Processing conversation 183
#   Correct topic: 'food' (will be in position 3)
#   Topic options: ['general_entertainment', 'quarrel', 'food', 'technology', 'fashion']
#
# Processing conversation 184
#   Correct topic: 'books' (will be in position 3)
#   Topic options: ['emotions', 'movies', 'books', 'quarrel', 'ageing']
#
# Processing conversation 185
#   Correct topic: 'movies' (will be in position 3)
#   Topic options: ['food', 'sports', 'movies', 'books', 'emotions']
#
# Processing conversation 186
#   Correct topic: 'fashion' (will be in position 3)
#   Topic options: ['general_entertainment', 'music', 'fashion', 'ageing', 'politics']
#
# Processing conversation 187
#   Correct topic: 'quarrel' (will be in position 3)
#   Topic options: ['ageing', 'fashion', 'quarrel', 'food', 'movies']
#
# Processing conversation 188
#   Correct topic: 'movies' (will be in position 3)
#   Topic options: ['sports', 'politics', 'movies', 'traffic', 'music']
#
# Processing conversation 189
#   Correct topic: 'traffic' (will be in position 3)
#   Topic options: ['general_entertainment', 'music', 'traffic', 'quarrel', 'movies']
#
# Processing conversation 190
#   Correct topic: 'general_entertainment' (will be in position 3)
#   Topic options: ['movies', 'fashion', 'general_entertainment', 'books', 'technology']
#
# Processing conversation 191
#   Correct topic: 'food' (will be in position 3)
#   Topic options: ['music', 'traffic', 'food', 'emotions', 'politics']
#
# Processing conversation 192
#   Correct topic: 'food' (will be in position 3)
#   Topic options: ['movies', 'books', 'food', 'quarrel', 'music']
#
# Processing conversation 193
#   Correct topic: 'technology' (will be in position 3)
#   Topic options: ['music', 'emotions', 'technology', 'traffic', 'quarrel']
#
# Processing conversation 194
#   Correct topic: 'technology' (will be in position 3)
#   Topic options: ['music', 'general_entertainment', 'technology', 'books', 'traffic']
#
# Processing conversation 195
#   Correct topic: 'fashion' (will be in position 3)
#   Topic options: ['emotions', 'movies', 'fashion', 'sports', 'books']
#
# Processing conversation 196
#   Correct topic: 'books' (will be in position 3)
#   Topic options: ['fashion', 'music', 'books', 'food', 'ageing']
#
# Processing conversation 197
#   Correct topic: 'sports' (will be in position 3)
#   Topic options: ['politics', 'music', 'sports', 'quarrel', 'food']
#
# Processing conversation 198
#   Correct topic: 'books' (will be in position 3)
#   Topic options: ['ageing', 'science', 'books', 'sports', 'food']
#
# Processing conversation 199
#   Correct topic: 'movies' (will be in position 3)
#   Topic options: ['music', 'books', 'movies', 'traffic', 'quarrel']
#
# Processing conversation 200
#   Correct topic: 'science' (will be in position 3)
#   Topic options: ['food', 'technology', 'science', 'politics', 'traffic']
#
# Processing conversation 201
#   Correct topic: 'books' (will be in position 3)
#   Topic options: ['fashion', 'traffic', 'books', 'general_entertainment', 'food']
#
# Processing conversation 202
#   Correct topic: 'music' (will be in position 3)
#   Topic options: ['politics', 'food', 'music', 'quarrel', 'emotions']
#
# Processing conversation 203
#   Correct topic: 'technology' (will be in position 3)
#   Topic options: ['general_entertainment', 'politics', 'technology', 'quarrel', 'traffic']
#
# Processing conversation 204
#   Correct topic: 'sports' (will be in position 3)
#   Topic options: ['books', 'quarrel', 'sports', 'traffic', 'science']
#
# Processing conversation 205
#   Correct topic: 'fashion' (will be in position 3)
#   Topic options: ['ageing', 'food', 'fashion', 'music', 'science']
#
# Processing conversation 206
#   Correct topic: 'fashion' (will be in position 3)
#   Topic options: ['technology', 'ageing', 'fashion', 'food', 'science']
#
# Processing conversation 207
#   Correct topic: 'technology' (will be in position 3)
#   Topic options: ['music', 'books', 'technology', 'politics', 'traffic']
#
# Processing conversation 208
#   Correct topic: 'music' (will be in position 3)
#   Topic options: ['politics', 'traffic', 'music', 'movies', 'books']
#
# Processing conversation 209
#   Correct topic: 'movies' (will be in position 3)
#   Topic options: ['general_entertainment', 'science', 'movies', 'ageing', 'politics']
#
# Processing conversation 210
#   Correct topic: 'music' (will be in position 3)
#   Topic options: ['ageing', 'food', 'music', 'fashion', 'general_entertainment']
#
# Processing conversation 211
#   Correct topic: 'movies' (will be in position 3)
#   Topic options: ['general_entertainment', 'traffic', 'movies', 'quarrel', 'fashion']
#
# Processing conversation 212
#   Correct topic: 'music' (will be in position 3)
#   Topic options: ['emotions', 'books', 'music', 'food', 'science']
#
# Processing conversation 213
#   Correct topic: 'food' (will be in position 3)
#   Topic options: ['movies', 'emotions', 'food', 'traffic', 'ageing']
#
# Processing conversation 214
#   Correct topic: 'politics' (will be in position 3)
#   Topic options: ['general_entertainment', 'quarrel', 'politics', 'science', 'emotions']
#
# Processing conversation 215
#   Correct topic: 'sports' (will be in position 3)
#   Topic options: ['politics', 'traffic', 'sports', 'science', 'fashion']
#
# Processing conversation 216
#   Correct topic: 'music' (will be in position 3)
#   Topic options: ['movies', 'books', 'music', 'general_entertainment', 'quarrel']
#
# Processing conversation 217
#   Correct topic: 'movies' (will be in position 3)
#   Topic options: ['sports', 'emotions', 'movies', 'fashion', 'traffic']
#
# Processing conversation 218
#   Correct topic: 'food' (will be in position 3)
#   Topic options: ['science', 'quarrel', 'food', 'traffic', 'fashion']
#
# Processing conversation 219
#   Correct topic: 'science' (will be in position 3)
#   Topic options: ['music', 'movies', 'science', 'ageing', 'food']
#
# Processing conversation 220
#   Correct topic: 'movies' (will be in position 3)
#   Topic options: ['music', 'sports', 'movies', 'quarrel', 'food']
#
# Processing conversation 221
#   Correct topic: 'technology' (will be in position 3)
#   Topic options: ['books', 'movies', 'technology', 'sports', 'quarrel']
#
# Processing conversation 222
#   Correct topic: 'sports' (will be in position 3)
#   Topic options: ['food', 'emotions', 'sports', 'politics', 'fashion']
#
# Processing conversation 223
#   Correct topic: 'fashion' (will be in position 3)
#   Topic options: ['quarrel', 'books', 'fashion', 'movies', 'technology']
#
# Processing conversation 224
#   Correct topic: 'books' (will be in position 4)
#   Topic options: ['fashion', 'technology', 'politics', 'books', 'quarrel']
#
# Processing conversation 225
#   Correct topic: 'science' (will be in position 4)
#   Topic options: ['sports', 'fashion', 'traffic', 'science', 'emotions']
#
# Processing conversation 226
#   Correct topic: 'politics' (will be in position 4)
#   Topic options: ['general_entertainment', 'food', 'books', 'politics', 'sports']
#
# Processing conversation 227
#   Correct topic: 'movies' (will be in position 4)
#   Topic options: ['food', 'sports', 'politics', 'movies', 'emotions']
#
# Processing conversation 228
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['quarrel', 'movies', 'traffic', 'technology', 'books']
#
# Processing conversation 229
#   Correct topic: 'fashion' (will be in position 4)
#   Topic options: ['music', 'ageing', 'politics', 'fashion', 'sports']
#
# Processing conversation 230
#   Correct topic: 'food' (will be in position 4)
#   Topic options: ['books', 'fashion', 'movies', 'food', 'emotions']
#
# Processing conversation 231
#   Correct topic: 'food' (will be in position 4)
#   Topic options: ['science', 'general_entertainment', 'emotions', 'food', 'music']
#
# Processing conversation 232
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['books', 'traffic', 'science', 'technology', 'fashion']
#
# Processing conversation 233
#   Correct topic: 'food' (will be in position 4)
#   Topic options: ['sports', 'quarrel', 'politics', 'food', 'ageing']
#
# Processing conversation 234
#   Correct topic: 'books' (will be in position 4)
#   Topic options: ['food', 'sports', 'politics', 'books', 'fashion']
#
# Processing conversation 235
#   Correct topic: 'music' (will be in position 4)
#   Topic options: ['ageing', 'quarrel', 'technology', 'music', 'books']
#
# Processing conversation 236
#   Correct topic: 'books' (will be in position 4)
#   Topic options: ['technology', 'politics', 'general_entertainment', 'books', 'movies']
#
# Processing conversation 237
#   Correct topic: 'science' (will be in position 4)
#   Topic options: ['music', 'ageing', 'politics', 'science', 'traffic']
#
# Processing conversation 238
#   Correct topic: 'movies' (will be in position 4)
#   Topic options: ['fashion', 'quarrel', 'books', 'movies', 'food']
#
# Processing conversation 239
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['politics', 'music', 'general_entertainment', 'technology', 'books']
#
# Processing conversation 240
#   Correct topic: 'general_entertainment' (will be in position 4)
#   Topic options: ['music', 'emotions', 'traffic', 'general_entertainment', 'movies']
#
# Processing conversation 241
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['movies', 'quarrel', 'emotions', 'technology', 'ageing']
#
# Processing conversation 242
#   Correct topic: 'general_entertainment' (will be in position 4)
#   Topic options: ['ageing', 'science', 'books', 'general_entertainment', 'technology']
#
# Processing conversation 243
#   Correct topic: 'books' (will be in position 4)
#   Topic options: ['general_entertainment', 'movies', 'technology', 'books', 'music']
#
# Processing conversation 244
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['food', 'sports', 'traffic', 'technology', 'ageing']
#
# Processing conversation 245
#   Correct topic: 'emotions' (will be in position 4)
#   Topic options: ['ageing', 'music', 'quarrel', 'emotions', 'technology']
#
# Processing conversation 246
#   Correct topic: 'music' (will be in position 4)
#   Topic options: ['general_entertainment', 'traffic', 'books', 'music', 'fashion']
#
# Processing conversation 247
#   Correct topic: 'food' (will be in position 4)
#   Topic options: ['music', 'emotions', 'politics', 'food', 'traffic']
#
# Processing conversation 248
#   Correct topic: 'science' (will be in position 4)
#   Topic options: ['politics', 'music', 'ageing', 'science', 'emotions']
#
# Processing conversation 249
#   Correct topic: 'food' (will be in position 4)
#   Topic options: ['sports', 'technology', 'politics', 'food', 'books']
#
# Processing conversation 250
#   Correct topic: 'politics' (will be in position 4)
#   Topic options: ['technology', 'ageing', 'emotions', 'politics', 'science']
#
# Processing conversation 251
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['emotions', 'general_entertainment', 'books', 'technology', 'sports']
#
# Processing conversation 252
#   Correct topic: 'fashion' (will be in position 4)
#   Topic options: ['ageing', 'emotions', 'food', 'fashion', 'quarrel']
#
# Processing conversation 253
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['food', 'movies', 'books', 'technology', 'fashion']
#
# Processing conversation 254
#   Correct topic: 'fashion' (will be in position 4)
#   Topic options: ['music', 'quarrel', 'emotions', 'fashion', 'books']
#
# Processing conversation 255
#   Correct topic: 'music' (will be in position 4)
#   Topic options: ['fashion', 'food', 'traffic', 'music', 'general_entertainment']
#
# Processing conversation 256
#   Correct topic: 'music' (will be in position 4)
#   Topic options: ['technology', 'traffic', 'food', 'music', 'books']
#
# Processing conversation 257
#   Correct topic: 'movies' (will be in position 4)
#   Topic options: ['sports', 'science', 'ageing', 'movies', 'emotions']
#
# Processing conversation 258
#   Correct topic: 'politics' (will be in position 4)
#   Topic options: ['fashion', 'traffic', 'science', 'politics', 'ageing']
#
# Processing conversation 259
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['traffic', 'movies', 'ageing', 'technology', 'books']
#
# Processing conversation 260
#   Correct topic: 'science' (will be in position 4)
#   Topic options: ['technology', 'sports', 'general_entertainment', 'science', 'music']
#
# Processing conversation 261
#   Correct topic: 'food' (will be in position 4)
#   Topic options: ['books', 'science', 'sports', 'food', 'politics']
#
# Processing conversation 262
#   Correct topic: 'movies' (will be in position 4)
#   Topic options: ['food', 'ageing', 'emotions', 'movies', 'music']
#
# Processing conversation 263
#   Correct topic: 'science' (will be in position 4)
#   Topic options: ['books', 'sports', 'movies', 'science', 'quarrel']
#
# Processing conversation 264
#   Correct topic: 'books' (will be in position 4)
#   Topic options: ['sports', 'emotions', 'traffic', 'books', 'politics']
#
# Processing conversation 265
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['politics', 'general_entertainment', 'science', 'technology', 'books']
#
# Processing conversation 266
#   Correct topic: 'music' (will be in position 4)
#   Topic options: ['general_entertainment', 'politics', 'technology', 'music', 'ageing']
#
# Processing complete!
# Successfully processed 176 conversations
# All files created in 'dataset' folder
# Files created:
# - Conversation snippets: conv*_len*.html
# - Topic options: conv*_len*option*.html

# %%
import linecache
import os
import glob
import pandas as pd
import random

# Configuration
source_folder = "/Users/elisapavarino/Documents/Work_Directory/Kreiman_Lab/Turing Test Paper/TuringGithub/conversation/conversation_task_for_revisions/new_dataset"  # CHANGE THIS: Path to folder containing conv*.html files
excel_file = "esChat.xlsx"  # Path to your Excel file
output_folder = "dataset"  # Output folder name
length_list = [3, 6, 9, 12, 15, 18, 21, 24]  # All required snippet lengths

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Read the Excel file
try:
    df = pd.read_excel(excel_file)
    print(f"Successfully loaded Excel file with {len(df)} rows")
    
    # Debug: Show DataFrame info
    print(f"\nDataFrame shape: {df.shape}")
    print(f"\nColumn names:")
    for i, col in enumerate(df.columns):
        print(f"  {i}: '{col}'")
    
    print(f"\nFirst few rows:")
    print(df.head())
    
    # Check if the expected columns exist
    required_columns = ['conversation_id', 'topic', 'topic_label']
    missing_columns = [col for col in required_columns if col not in df.columns]
    
    if missing_columns:
        print(f"\nERROR: Missing required columns: {missing_columns}")
        print("Please check your Excel file column names.")
        exit(1)
    
except Exception as e:
    print(f"Error loading Excel file: {e}")
    exit(1)

# Get all unique topics (excluding the correct one for each conversation)
all_topics = df['topic'].unique().tolist()
print(f"Found {len(all_topics)} unique topics: {all_topics}")

# Find all conversation files in the source folder
conv_files = glob.glob(os.path.join(source_folder, "conv*.html"))
conv_numbers = []

# Extract conversation numbers from filenames
for file in conv_files:
    filename = os.path.basename(file)
    if filename.startswith("conv") and filename.endswith(".html"):
        try:
            # Extract number from filename like "conv123.html"
            num_str = filename[4:-5]  # Remove "conv" and ".html"
            if num_str.isdigit():
                conv_numbers.append(int(num_str))
        except:
            continue

# Sort conversation numbers
conv_numbers.sort()
print(f"Found conversation files: {conv_numbers}")

# Process each conversation
processed_count = 0
for conv_num in conv_numbers:
    # Find this conversation in the Excel file
    conv_row = df[df['conversation_id'] == conv_num]
    
    if conv_row.empty:
        print(f"Warning: Conversation {conv_num} not found in Excel file, skipping...")
        continue
    
    conv_data = conv_row.iloc[0]
    correct_topic = conv_data['topic']
    topic_label = int(conv_data['topic_label'])  # Which position (1-5) the correct topic should be in
    
    print(f"\nProcessing conversation {conv_num}")
    print(f"  Correct topic: '{correct_topic}' (will be in position {topic_label})")
    
    original_file = os.path.join(source_folder, f'conv{conv_num}.html')
    
    # Check if original conversation file exists
    if not os.path.exists(original_file):
        print(f"Warning: {original_file} not found, skipping...")
        continue
    
    # Generate 4 other topics (excluding the correct one)
    other_topics = [topic for topic in all_topics if topic != correct_topic]
    random.shuffle(other_topics)
    selected_other_topics = other_topics[:4]  # Take first 4 after shuffle
    
    # Create the 5 topics list with correct topic in the right position
    topics_list = [None] * 5
    topics_list[topic_label - 1] = correct_topic  # topic_label is 1-based
    
    # Fill the remaining positions with the other topics
    other_index = 0
    for i in range(5):
        if topics_list[i] is None:
            topics_list[i] = selected_other_topics[other_index]
            other_index += 1
    
    print(f"  Topic options: {topics_list}")
    
    # Create snippets for each length
    for length in length_list:
        # Create main snippet file
        snippet_filename = os.path.join(output_folder, f'conv{conv_num}_len{length}.html')
        
        with open(snippet_filename, "w", encoding='utf-8') as file_html:
            # Write the HTML header with script
            file_html.write("<script>\n")
            file_html.write(" window.addEventListener('load', function() { let message = { height: document.body.scrollHeight, width: document.body.scrollWidth }; window.top.postMessage(message, '*'); }); \n")
            file_html.write(" </script> \n")
            file_html.write(" <font size='3'>\n")
            
            # Write the conversation snippet with alternating colors
            for line in range(1, length + 1):
                particular_line = linecache.getline(original_file, line).strip()
                if particular_line and particular_line.startswith('<p>'):
                    # Extract the content between <p> and </p>
                    # Expected format: <p> A: content </p> or <p> B: content </p>
                    content = particular_line.replace('<p>', '').replace('</p>', '').strip()
                    
                    if content.startswith('A:'):
                        # Speaker A in dark blue
                        formatted_line = f'<FONT COLOR=darkblue><p style="margin-bottom:-18px;">{content}</p> \n</FONT>'
                    elif content.startswith('B:'):
                        # Speaker B in crimson
                        formatted_line = f'<FONT COLOR=crimson><p style="margin-bottom:-18px;">{content}</p> \n</FONT>'
                    else:
                        # Fallback: keep original format
                        formatted_line = particular_line + '\n'
                    
                    file_html.write(formatted_line)
            
            # Close the font tag
            file_html.write("</font>\n")
        
        # Create 5 option files with the topics
        for option_num in range(1, 6):
            option_filename = os.path.join(output_folder, f'conv{conv_num}_len{length}option{option_num}.html')
            
            with open(option_filename, "w", encoding='utf-8') as option_file:
                option_file.write(topics_list[option_num - 1])
    
    processed_count += 1

print(f"\nProcessing complete!")
print(f"Successfully processed {processed_count} conversations")
print(f"All files created in '{output_folder}' folder")
print("Files created:")
print("- Conversation snippets: conv*_len*.html")
print("- Topic options: conv*_len*option*.html")

# Clear linecache to free memory
linecache.clearcache()
# Out:
# Successfully loaded Excel file with 210 rows
#
# DataFrame shape: (210, 17)
#
# Column names:
#   0: 'conversation_id'
#   1: 'Conv_label'
#   2: 'mcq'
#   3: 'A_label'
#   4: 'A_age'
#   5: 'A_gender'
#   6: 'B_label'
#   7: 'B_age'
#   8: 'B_gender'
#   9: 'A_judgeByB'
#   10: 'A_age_judgeByB'
#   11: 'A_gender_judgeByB'
#   12: 'B_judgeByA'
#   13: 'B_age_judgeByA'
#   14: 'B_gender_judgebyA'
#   15: 'topic'
#   16: 'topic_label'
#
# First few rows:
#    conversation_id           Conv_label  mcq A_label              A_age  \
# 0               34         GPT-4o-Human   24      AI  26 - 30 years old
# 1               35          Human-Human   12   Human  31 - 35 years old
# 2               46          Human-Human   12   Human  21 - 25 years old
# 3               55         GPT-4o-Human   24      AI  31 - 35 years old
# 4               57  Human-Llama-3.3-70B   12   Human  26 - 30 years old
#
#   A_gender B_label               B_age B_gender A_judgeByB     A_age_judgeByB  \
# 0   Female   Human   26 - 30 years old     Male         AI  31 - 35 years old
# 1   Female   Human  above 50 years old     Male      Human  26 - 30 years old
# 2     Male   Human   31 - 35 years old   Female        NaN                NaN
# 3   Female   Human   26 - 30 years old   Female         AI  31 - 35 years old
# 4   Female      AI   18 - 20 years old     Male        NaN                NaN
#
#   A_gender_judgeByB B_judgeByA     B_age_judgeByA B_gender_judgebyA     topic  \
# 0              Male        NaN                NaN               NaN    sports
# 1            Female      Human  46 - 50 years old              Male   science
# 2               NaN        NaN                NaN               NaN  politics
# 3            Female        NaN                NaN               NaN    movies
# 4               NaN      Human  21 - 25 years old              Male   fashion
#
#    topic_label
# 0            5
# 1            5
# 2            5
# 3            5
# 4            5
# Found 14 unique topics: ['sports', 'science', 'politics', 'movies', 'fashion', 'music', 'general_entertainment', 'books', 'food', 'technology', 'quarrel', 'traffic', 'emotions', 'ageing']
# Found conversation files: [35, 46, 57, 58, 60, 61, 62, 63, 65, 67, 68, 69, 70, 73, 75, 76, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 93, 94, 95, 96, 97, 98, 99, 100, 101, 103, 104, 105, 106, 107, 109, 110, 111, 113, 114, 115, 116, 117, 118, 120, 121, 122, 123, 124, 126, 127, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 142, 146, 149, 150, 154, 155, 156, 158, 159, 160, 162, 164, 171, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266]
#
# Processing conversation 35
#   Correct topic: 'science' (will be in position 5)
#   Topic options: ['food', 'technology', 'ageing', 'music', 'science']
#
# Processing conversation 46
#   Correct topic: 'politics' (will be in position 5)
#   Topic options: ['fashion', 'food', 'quarrel', 'ageing', 'politics']
#
# Processing conversation 57
#   Correct topic: 'fashion' (will be in position 5)
#   Topic options: ['emotions', 'general_entertainment', 'sports', 'music', 'fashion']
#
# Processing conversation 58
#   Correct topic: 'music' (will be in position 5)
#   Topic options: ['science', 'quarrel', 'books', 'sports', 'music']
#
# Processing conversation 60
#   Correct topic: 'politics' (will be in position 5)
#   Topic options: ['books', 'food', 'general_entertainment', 'traffic', 'politics']
#
# Processing conversation 61
#   Correct topic: 'politics' (will be in position 5)
#   Topic options: ['technology', 'books', 'ageing', 'food', 'politics']
#
# Processing conversation 62
#   Correct topic: 'general_entertainment' (will be in position 5)
#   Topic options: ['technology', 'quarrel', 'books', 'fashion', 'general_entertainment']
#
# Processing conversation 63
#   Correct topic: 'science' (will be in position 5)
#   Topic options: ['technology', 'music', 'quarrel', 'fashion', 'science']
#
# Processing conversation 65
#   Correct topic: 'music' (will be in position 1)
#   Topic options: ['music', 'movies', 'technology', 'general_entertainment', 'traffic']
#
# Processing conversation 67
#   Correct topic: 'fashion' (will be in position 1)
#   Topic options: ['fashion', 'sports', 'ageing', 'general_entertainment', 'politics']
#
# Processing conversation 68
#   Correct topic: 'fashion' (will be in position 1)
#   Topic options: ['fashion', 'politics', 'science', 'music', 'food']
#
# Processing conversation 69
#   Correct topic: 'music' (will be in position 1)
#   Topic options: ['music', 'traffic', 'quarrel', 'science', 'fashion']
#
# Processing conversation 70
#   Correct topic: 'fashion' (will be in position 1)
#   Topic options: ['fashion', 'ageing', 'politics', 'technology', 'traffic']
#
# Processing conversation 73
#   Correct topic: 'sports' (will be in position 1)
#   Topic options: ['sports', 'general_entertainment', 'ageing', 'music', 'politics']
#
# Processing conversation 75
#   Correct topic: 'books' (will be in position 1)
#   Topic options: ['books', 'movies', 'traffic', 'technology', 'general_entertainment']
#
# Processing conversation 76
#   Correct topic: 'sports' (will be in position 1)
#   Topic options: ['sports', 'fashion', 'general_entertainment', 'quarrel', 'food']
#
# Processing conversation 79
#   Correct topic: 'politics' (will be in position 1)
#   Topic options: ['politics', 'quarrel', 'emotions', 'technology', 'food']
#
# Processing conversation 80
#   Correct topic: 'food' (will be in position 1)
#   Topic options: ['food', 'politics', 'quarrel', 'general_entertainment', 'emotions']
#
# Processing conversation 81
#   Correct topic: 'movies' (will be in position 1)
#   Topic options: ['movies', 'ageing', 'general_entertainment', 'emotions', 'technology']
#
# Processing conversation 82
#   Correct topic: 'politics' (will be in position 1)
#   Topic options: ['politics', 'books', 'general_entertainment', 'emotions', 'ageing']
#
# Processing conversation 83
#   Correct topic: 'politics' (will be in position 1)
#   Topic options: ['politics', 'ageing', 'books', 'music', 'technology']
#
# Processing conversation 84
#   Correct topic: 'music' (will be in position 1)
#   Topic options: ['music', 'movies', 'sports', 'politics', 'quarrel']
#
# Processing conversation 85
#   Correct topic: 'science' (will be in position 1)
#   Topic options: ['science', 'technology', 'music', 'emotions', 'food']
#
# Processing conversation 86
#   Correct topic: 'music' (will be in position 1)
#   Topic options: ['music', 'politics', 'technology', 'movies', 'sports']
#
# Processing conversation 87
#   Correct topic: 'books' (will be in position 1)
#   Topic options: ['books', 'politics', 'emotions', 'science', 'quarrel']
#
# Processing conversation 88
#   Correct topic: 'science' (will be in position 1)
#   Topic options: ['science', 'emotions', 'quarrel', 'sports', 'ageing']
#
# Processing conversation 89
#   Correct topic: 'technology' (will be in position 1)
#   Topic options: ['technology', 'traffic', 'politics', 'ageing', 'sports']
#
# Processing conversation 90
#   Correct topic: 'technology' (will be in position 1)
#   Topic options: ['technology', 'movies', 'emotions', 'traffic', 'ageing']
#
# Processing conversation 91
#   Correct topic: 'politics' (will be in position 1)
#   Topic options: ['politics', 'books', 'food', 'fashion', 'technology']
#
# Processing conversation 93
#   Correct topic: 'books' (will be in position 1)
#   Topic options: ['books', 'emotions', 'general_entertainment', 'food', 'technology']
#
# Processing conversation 94
#   Correct topic: 'music' (will be in position 1)
#   Topic options: ['music', 'movies', 'traffic', 'ageing', 'politics']
#
# Processing conversation 95
#   Correct topic: 'science' (will be in position 1)
#   Topic options: ['science', 'sports', 'traffic', 'music', 'food']
#
# Processing conversation 96
#   Correct topic: 'books' (will be in position 1)
#   Topic options: ['books', 'quarrel', 'technology', 'general_entertainment', 'science']
#
# Processing conversation 97
#   Correct topic: 'food' (will be in position 1)
#   Topic options: ['food', 'emotions', 'ageing', 'technology', 'fashion']
#
# Processing conversation 98
#   Correct topic: 'food' (will be in position 1)
#   Topic options: ['food', 'books', 'quarrel', 'politics', 'science']
#
# Processing conversation 99
#   Correct topic: 'science' (will be in position 1)
#   Topic options: ['science', 'emotions', 'music', 'politics', 'food']
#
# Processing conversation 100
#   Correct topic: 'books' (will be in position 1)
#   Topic options: ['books', 'food', 'general_entertainment', 'ageing', 'music']
#
# Processing conversation 101
#   Correct topic: 'fashion' (will be in position 1)
#   Topic options: ['fashion', 'quarrel', 'books', 'science', 'sports']
#
# Processing conversation 103
#   Correct topic: 'movies' (will be in position 1)
#   Topic options: ['movies', 'ageing', 'technology', 'books', 'traffic']
#
# Processing conversation 104
#   Correct topic: 'technology' (will be in position 1)
#   Topic options: ['technology', 'food', 'books', 'movies', 'music']
#
# Processing conversation 105
#   Correct topic: 'food' (will be in position 1)
#   Topic options: ['food', 'technology', 'sports', 'politics', 'fashion']
#
# Processing conversation 106
#   Correct topic: 'politics' (will be in position 1)
#   Topic options: ['politics', 'science', 'quarrel', 'traffic', 'sports']
#
# Processing conversation 107
#   Correct topic: 'food' (will be in position 1)
#   Topic options: ['food', 'general_entertainment', 'music', 'sports', 'politics']
#
# Processing conversation 109
#   Correct topic: 'general_entertainment' (will be in position 1)
#   Topic options: ['general_entertainment', 'science', 'politics', 'food', 'ageing']
#
# Processing conversation 110
#   Correct topic: 'technology' (will be in position 2)
#   Topic options: ['politics', 'technology', 'food', 'traffic', 'books']
#
# Processing conversation 111
#   Correct topic: 'politics' (will be in position 2)
#   Topic options: ['traffic', 'politics', 'music', 'food', 'emotions']
#
# Processing conversation 113
#   Correct topic: 'science' (will be in position 2)
#   Topic options: ['quarrel', 'science', 'technology', 'books', 'food']
#
# Processing conversation 114
#   Correct topic: 'food' (will be in position 2)
#   Topic options: ['fashion', 'food', 'emotions', 'sports', 'movies']
#
# Processing conversation 115
#   Correct topic: 'politics' (will be in position 2)
#   Topic options: ['books', 'politics', 'movies', 'food', 'quarrel']
#
# Processing conversation 116
#   Correct topic: 'science' (will be in position 2)
#   Topic options: ['sports', 'science', 'politics', 'quarrel', 'technology']
#
# Processing conversation 117
#   Correct topic: 'technology' (will be in position 2)
#   Topic options: ['music', 'technology', 'ageing', 'politics', 'sports']
#
# Processing conversation 118
#   Correct topic: 'food' (will be in position 2)
#   Topic options: ['quarrel', 'food', 'technology', 'music', 'general_entertainment']
#
# Processing conversation 120
#   Correct topic: 'books' (will be in position 2)
#   Topic options: ['traffic', 'books', 'politics', 'general_entertainment', 'fashion']
#
# Processing conversation 121
#   Correct topic: 'politics' (will be in position 2)
#   Topic options: ['traffic', 'politics', 'music', 'sports', 'books']
#
# Processing conversation 122
#   Correct topic: 'general_entertainment' (will be in position 2)
#   Topic options: ['music', 'general_entertainment', 'quarrel', 'technology', 'sports']
#
# Processing conversation 123
#   Correct topic: 'food' (will be in position 2)
#   Topic options: ['science', 'food', 'books', 'music', 'ageing']
#
# Processing conversation 124
#   Correct topic: 'movies' (will be in position 2)
#   Topic options: ['food', 'movies', 'general_entertainment', 'politics', 'ageing']
#
# Processing conversation 126
#   Correct topic: 'general_entertainment' (will be in position 2)
#   Topic options: ['emotions', 'general_entertainment', 'books', 'politics', 'science']
#
# Processing conversation 127
#   Correct topic: 'politics' (will be in position 2)
#   Topic options: ['food', 'politics', 'books', 'movies', 'science']
#
# Processing conversation 129
#   Correct topic: 'fashion' (will be in position 2)
#   Topic options: ['sports', 'fashion', 'movies', 'quarrel', 'books']
#
# Processing conversation 130
#   Correct topic: 'fashion' (will be in position 2)
#   Topic options: ['traffic', 'fashion', 'movies', 'general_entertainment', 'music']
#
# Processing conversation 131
#   Correct topic: 'sports' (will be in position 2)
#   Topic options: ['books', 'sports', 'technology', 'ageing', 'politics']
#
# Processing conversation 132
#   Correct topic: 'books' (will be in position 2)
#   Topic options: ['movies', 'books', 'food', 'sports', 'music']
#
# Processing conversation 133
#   Correct topic: 'fashion' (will be in position 2)
#   Topic options: ['general_entertainment', 'fashion', 'ageing', 'books', 'politics']
#
# Processing conversation 134
#   Correct topic: 'science' (will be in position 2)
#   Topic options: ['music', 'science', 'fashion', 'general_entertainment', 'politics']
#
# Processing conversation 135
#   Correct topic: 'food' (will be in position 2)
#   Topic options: ['music', 'food', 'books', 'quarrel', 'ageing']
#
# Processing conversation 136
#   Correct topic: 'music' (will be in position 2)
#   Topic options: ['sports', 'music', 'science', 'quarrel', 'technology']
#
# Processing conversation 137
#   Correct topic: 'science' (will be in position 2)
#   Topic options: ['music', 'science', 'food', 'emotions', 'quarrel']
#
# Processing conversation 138
#   Correct topic: 'food' (will be in position 2)
#   Topic options: ['sports', 'food', 'quarrel', 'ageing', 'technology']
#
# Processing conversation 139
#   Correct topic: 'technology' (will be in position 2)
#   Topic options: ['food', 'technology', 'ageing', 'books', 'emotions']
#
# Processing conversation 142
#   Correct topic: 'science' (will be in position 2)
#   Topic options: ['sports', 'science', 'movies', 'ageing', 'technology']
#
# Processing conversation 146
#   Correct topic: 'science' (will be in position 2)
#   Topic options: ['quarrel', 'science', 'fashion', 'emotions', 'technology']
#
# Processing conversation 149
#   Correct topic: 'food' (will be in position 2)
#   Topic options: ['sports', 'food', 'quarrel', 'movies', 'music']
#
# Processing conversation 150
#   Correct topic: 'fashion' (will be in position 2)
#   Topic options: ['emotions', 'fashion', 'food', 'technology', 'politics']
#
# Processing conversation 154
#   Correct topic: 'music' (will be in position 2)
#   Topic options: ['quarrel', 'music', 'technology', 'general_entertainment', 'fashion']
#
# Processing conversation 155
#   Correct topic: 'fashion' (will be in position 2)
#   Topic options: ['movies', 'fashion', 'traffic', 'politics', 'food']
#
# Processing conversation 156
#   Correct topic: 'sports' (will be in position 2)
#   Topic options: ['music', 'sports', 'food', 'traffic', 'general_entertainment']
#
# Processing conversation 158
#   Correct topic: 'music' (will be in position 2)
#   Topic options: ['movies', 'music', 'science', 'sports', 'traffic']
#
# Processing conversation 159
#   Correct topic: 'politics' (will be in position 2)
#   Topic options: ['emotions', 'politics', 'food', 'sports', 'ageing']
#
# Processing conversation 160
#   Correct topic: 'science' (will be in position 2)
#   Topic options: ['technology', 'science', 'books', 'traffic', 'quarrel']
#
# Processing conversation 162
#   Correct topic: 'politics' (will be in position 2)
#   Topic options: ['books', 'politics', 'music', 'technology', 'quarrel']
#
# Processing conversation 164
#   Correct topic: 'technology' (will be in position 2)
#   Topic options: ['food', 'technology', 'movies', 'general_entertainment', 'science']
#
# Processing conversation 171
#   Correct topic: 'music' (will be in position 2)
#   Topic options: ['food', 'music', 'movies', 'books', 'quarrel']
#
# Processing conversation 174
#   Correct topic: 'sports' (will be in position 3)
#   Topic options: ['fashion', 'science', 'sports', 'food', 'politics']
#
# Processing conversation 175
#   Correct topic: 'food' (will be in position 3)
#   Topic options: ['sports', 'quarrel', 'food', 'music', 'general_entertainment']
#
# Processing conversation 176
#   Correct topic: 'technology' (will be in position 3)
#   Topic options: ['general_entertainment', 'fashion', 'technology', 'food', 'emotions']
#
# Processing conversation 177
#   Correct topic: 'music' (will be in position 3)
#   Topic options: ['ageing', 'emotions', 'music', 'politics', 'movies']
#
# Processing conversation 178
#   Correct topic: 'movies' (will be in position 3)
#   Topic options: ['quarrel', 'emotions', 'movies', 'traffic', 'sports']
#
# Processing conversation 179
#   Correct topic: 'fashion' (will be in position 3)
#   Topic options: ['politics', 'music', 'fashion', 'sports', 'general_entertainment']
#
# Processing conversation 180
#   Correct topic: 'food' (will be in position 3)
#   Topic options: ['general_entertainment', 'science', 'food', 'quarrel', 'traffic']
#
# Processing conversation 181
#   Correct topic: 'fashion' (will be in position 3)
#   Topic options: ['traffic', 'technology', 'fashion', 'music', 'movies']
#
# Processing conversation 182
#   Correct topic: 'music' (will be in position 3)
#   Topic options: ['food', 'traffic', 'music', 'technology', 'fashion']
#
# Processing conversation 183
#   Correct topic: 'food' (will be in position 3)
#   Topic options: ['fashion', 'ageing', 'food', 'science', 'politics']
#
# Processing conversation 184
#   Correct topic: 'books' (will be in position 3)
#   Topic options: ['fashion', 'politics', 'books', 'ageing', 'music']
#
# Processing conversation 185
#   Correct topic: 'movies' (will be in position 3)
#   Topic options: ['fashion', 'general_entertainment', 'movies', 'science', 'sports']
#
# Processing conversation 186
#   Correct topic: 'fashion' (will be in position 3)
#   Topic options: ['politics', 'books', 'fashion', 'ageing', 'technology']
#
# Processing conversation 187
#   Correct topic: 'quarrel' (will be in position 3)
#   Topic options: ['fashion', 'science', 'quarrel', 'traffic', 'general_entertainment']
#
# Processing conversation 188
#   Correct topic: 'movies' (will be in position 3)
#   Topic options: ['ageing', 'emotions', 'movies', 'technology', 'science']
#
# Processing conversation 189
#   Correct topic: 'traffic' (will be in position 3)
#   Topic options: ['emotions', 'ageing', 'traffic', 'quarrel', 'politics']
#
# Processing conversation 190
#   Correct topic: 'general_entertainment' (will be in position 3)
#   Topic options: ['emotions', 'movies', 'general_entertainment', 'traffic', 'science']
#
# Processing conversation 191
#   Correct topic: 'food' (will be in position 3)
#   Topic options: ['general_entertainment', 'movies', 'food', 'quarrel', 'traffic']
#
# Processing conversation 192
#   Correct topic: 'food' (will be in position 3)
#   Topic options: ['ageing', 'books', 'food', 'technology', 'general_entertainment']
#
# Processing conversation 193
#   Correct topic: 'technology' (will be in position 3)
#   Topic options: ['quarrel', 'fashion', 'technology', 'ageing', 'music']
#
# Processing conversation 194
#   Correct topic: 'technology' (will be in position 3)
#   Topic options: ['politics', 'books', 'technology', 'sports', 'food']
#
# Processing conversation 195
#   Correct topic: 'fashion' (will be in position 3)
#   Topic options: ['traffic', 'science', 'fashion', 'movies', 'general_entertainment']
#
# Processing conversation 196
#   Correct topic: 'books' (will be in position 3)
#   Topic options: ['movies', 'technology', 'books', 'quarrel', 'ageing']
#
# Processing conversation 197
#   Correct topic: 'sports' (will be in position 3)
#   Topic options: ['quarrel', 'politics', 'sports', 'emotions', 'movies']
#
# Processing conversation 198
#   Correct topic: 'books' (will be in position 3)
#   Topic options: ['traffic', 'emotions', 'books', 'movies', 'food']
#
# Processing conversation 199
#   Correct topic: 'movies' (will be in position 3)
#   Topic options: ['books', 'fashion', 'movies', 'ageing', 'technology']
#
# Processing conversation 200
#   Correct topic: 'science' (will be in position 3)
#   Topic options: ['politics', 'music', 'science', 'books', 'food']
#
# Processing conversation 201
#   Correct topic: 'books' (will be in position 3)
#   Topic options: ['movies', 'fashion', 'books', 'science', 'ageing']
#
# Processing conversation 202
#   Correct topic: 'music' (will be in position 3)
#   Topic options: ['sports', 'technology', 'music', 'science', 'books']
#
# Processing conversation 203
#   Correct topic: 'technology' (will be in position 3)
#   Topic options: ['quarrel', 'emotions', 'technology', 'fashion', 'science']
#
# Processing conversation 204
#   Correct topic: 'sports' (will be in position 3)
#   Topic options: ['ageing', 'books', 'sports', 'quarrel', 'science']
#
# Processing conversation 205
#   Correct topic: 'fashion' (will be in position 3)
#   Topic options: ['books', 'movies', 'fashion', 'general_entertainment', 'sports']
#
# Processing conversation 206
#   Correct topic: 'fashion' (will be in position 3)
#   Topic options: ['food', 'quarrel', 'fashion', 'traffic', 'movies']
#
# Processing conversation 207
#   Correct topic: 'technology' (will be in position 3)
#   Topic options: ['fashion', 'sports', 'technology', 'books', 'quarrel']
#
# Processing conversation 208
#   Correct topic: 'music' (will be in position 3)
#   Topic options: ['ageing', 'technology', 'music', 'quarrel', 'food']
#
# Processing conversation 209
#   Correct topic: 'movies' (will be in position 3)
#   Topic options: ['technology', 'food', 'movies', 'sports', 'books']
#
# Processing conversation 210
#   Correct topic: 'music' (will be in position 3)
#   Topic options: ['sports', 'books', 'music', 'science', 'fashion']
#
# Processing conversation 211
#   Correct topic: 'movies' (will be in position 3)
#   Topic options: ['music', 'sports', 'movies', 'traffic', 'ageing']
#
# Processing conversation 212
#   Correct topic: 'music' (will be in position 3)
#   Topic options: ['technology', 'science', 'music', 'books', 'ageing']
#
# Processing conversation 213
#   Correct topic: 'food' (will be in position 3)
#   Topic options: ['technology', 'quarrel', 'food', 'movies', 'emotions']
#
# Processing conversation 214
#   Correct topic: 'politics' (will be in position 3)
#   Topic options: ['music', 'general_entertainment', 'politics', 'ageing', 'traffic']
#
# Processing conversation 215
#   Correct topic: 'sports' (will be in position 3)
#   Topic options: ['emotions', 'music', 'sports', 'technology', 'politics']
#
# Processing conversation 216
#   Correct topic: 'music' (will be in position 3)
#   Topic options: ['traffic', 'sports', 'music', 'technology', 'emotions']
#
# Processing conversation 217
#   Correct topic: 'movies' (will be in position 3)
#   Topic options: ['sports', 'ageing', 'movies', 'science', 'technology']
#
# Processing conversation 218
#   Correct topic: 'food' (will be in position 3)
#   Topic options: ['sports', 'technology', 'food', 'politics', 'books']
#
# Processing conversation 219
#   Correct topic: 'science' (will be in position 3)
#   Topic options: ['books', 'emotions', 'science', 'fashion', 'food']
#
# Processing conversation 220
#   Correct topic: 'movies' (will be in position 3)
#   Topic options: ['food', 'sports', 'movies', 'fashion', 'emotions']
#
# Processing conversation 221
#   Correct topic: 'technology' (will be in position 3)
#   Topic options: ['science', 'movies', 'technology', 'books', 'emotions']
#
# Processing conversation 222
#   Correct topic: 'sports' (will be in position 3)
#   Topic options: ['books', 'fashion', 'sports', 'movies', 'music']
#
# Processing conversation 223
#   Correct topic: 'fashion' (will be in position 3)
#   Topic options: ['ageing', 'food', 'fashion', 'music', 'sports']
#
# Processing conversation 224
#   Correct topic: 'books' (will be in position 4)
#   Topic options: ['sports', 'emotions', 'traffic', 'books', 'quarrel']
#
# Processing conversation 225
#   Correct topic: 'science' (will be in position 4)
#   Topic options: ['technology', 'sports', 'books', 'science', 'ageing']
#
# Processing conversation 226
#   Correct topic: 'politics' (will be in position 4)
#   Topic options: ['ageing', 'quarrel', 'music', 'politics', 'emotions']
#
# Processing conversation 227
#   Correct topic: 'movies' (will be in position 4)
#   Topic options: ['ageing', 'traffic', 'music', 'movies', 'quarrel']
#
# Processing conversation 228
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['ageing', 'music', 'politics', 'technology', 'traffic']
#
# Processing conversation 229
#   Correct topic: 'fashion' (will be in position 4)
#   Topic options: ['science', 'movies', 'quarrel', 'fashion', 'sports']
#
# Processing conversation 230
#   Correct topic: 'food' (will be in position 4)
#   Topic options: ['music', 'technology', 'science', 'food', 'traffic']
#
# Processing conversation 231
#   Correct topic: 'food' (will be in position 4)
#   Topic options: ['emotions', 'fashion', 'ageing', 'food', 'movies']
#
# Processing conversation 232
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['food', 'music', 'books', 'technology', 'science']
#
# Processing conversation 233
#   Correct topic: 'food' (will be in position 4)
#   Topic options: ['ageing', 'politics', 'books', 'food', 'sports']
#
# Processing conversation 234
#   Correct topic: 'books' (will be in position 4)
#   Topic options: ['movies', 'fashion', 'quarrel', 'books', 'general_entertainment']
#
# Processing conversation 235
#   Correct topic: 'music' (will be in position 4)
#   Topic options: ['fashion', 'food', 'science', 'music', 'general_entertainment']
#
# Processing conversation 236
#   Correct topic: 'books' (will be in position 4)
#   Topic options: ['general_entertainment', 'quarrel', 'sports', 'books', 'ageing']
#
# Processing conversation 237
#   Correct topic: 'science' (will be in position 4)
#   Topic options: ['books', 'fashion', 'food', 'science', 'emotions']
#
# Processing conversation 238
#   Correct topic: 'movies' (will be in position 4)
#   Topic options: ['technology', 'emotions', 'politics', 'movies', 'general_entertainment']
#
# Processing conversation 239
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['politics', 'quarrel', 'science', 'technology', 'music']
#
# Processing conversation 240
#   Correct topic: 'general_entertainment' (will be in position 4)
#   Topic options: ['ageing', 'fashion', 'technology', 'general_entertainment', 'sports']
#
# Processing conversation 241
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['traffic', 'science', 'ageing', 'technology', 'music']
#
# Processing conversation 242
#   Correct topic: 'general_entertainment' (will be in position 4)
#   Topic options: ['emotions', 'food', 'fashion', 'general_entertainment', 'traffic']
#
# Processing conversation 243
#   Correct topic: 'books' (will be in position 4)
#   Topic options: ['general_entertainment', 'traffic', 'sports', 'books', 'emotions']
#
# Processing conversation 244
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['ageing', 'quarrel', 'general_entertainment', 'technology', 'traffic']
#
# Processing conversation 245
#   Correct topic: 'emotions' (will be in position 4)
#   Topic options: ['ageing', 'books', 'movies', 'emotions', 'music']
#
# Processing conversation 246
#   Correct topic: 'music' (will be in position 4)
#   Topic options: ['food', 'quarrel', 'general_entertainment', 'music', 'ageing']
#
# Processing conversation 247
#   Correct topic: 'food' (will be in position 4)
#   Topic options: ['science', 'music', 'sports', 'food', 'quarrel']
#
# Processing conversation 248
#   Correct topic: 'science' (will be in position 4)
#   Topic options: ['emotions', 'technology', 'politics', 'science', 'sports']
#
# Processing conversation 249
#   Correct topic: 'food' (will be in position 4)
#   Topic options: ['politics', 'music', 'quarrel', 'food', 'books']
#
# Processing conversation 250
#   Correct topic: 'politics' (will be in position 4)
#   Topic options: ['sports', 'food', 'general_entertainment', 'politics', 'quarrel']
#
# Processing conversation 251
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['movies', 'fashion', 'quarrel', 'technology', 'emotions']
#
# Processing conversation 252
#   Correct topic: 'fashion' (will be in position 4)
#   Topic options: ['traffic', 'quarrel', 'music', 'fashion', 'general_entertainment']
#
# Processing conversation 253
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['movies', 'books', 'music', 'technology', 'sports']
#
# Processing conversation 254
#   Correct topic: 'fashion' (will be in position 4)
#   Topic options: ['books', 'emotions', 'politics', 'fashion', 'quarrel']
#
# Processing conversation 255
#   Correct topic: 'music' (will be in position 4)
#   Topic options: ['movies', 'traffic', 'technology', 'music', 'quarrel']
#
# Processing conversation 256
#   Correct topic: 'music' (will be in position 4)
#   Topic options: ['technology', 'food', 'politics', 'music', 'quarrel']
#
# Processing conversation 257
#   Correct topic: 'movies' (will be in position 4)
#   Topic options: ['books', 'emotions', 'quarrel', 'movies', 'general_entertainment']
#
# Processing conversation 258
#   Correct topic: 'politics' (will be in position 4)
#   Topic options: ['movies', 'general_entertainment', 'science', 'politics', 'books']
#
# Processing conversation 259
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['books', 'science', 'general_entertainment', 'technology', 'food']
#
# Processing conversation 260
#   Correct topic: 'science' (will be in position 4)
#   Topic options: ['sports', 'ageing', 'movies', 'science', 'quarrel']
#
# Processing conversation 261
#   Correct topic: 'food' (will be in position 4)
#   Topic options: ['quarrel', 'technology', 'movies', 'food', 'music']
#
# Processing conversation 262
#   Correct topic: 'movies' (will be in position 4)
#   Topic options: ['ageing', 'food', 'general_entertainment', 'movies', 'quarrel']
#
# Processing conversation 263
#   Correct topic: 'science' (will be in position 4)
#   Topic options: ['sports', 'politics', 'emotions', 'science', 'books']
#
# Processing conversation 264
#   Correct topic: 'books' (will be in position 4)
#   Topic options: ['technology', 'general_entertainment', 'food', 'books', 'traffic']
#
# Processing conversation 265
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['traffic', 'movies', 'emotions', 'technology', 'sports']
#
# Processing conversation 266
#   Correct topic: 'music' (will be in position 4)
#   Topic options: ['science', 'technology', 'quarrel', 'music', 'politics']
#
# Processing complete!
# Successfully processed 176 conversations
# All files created in 'dataset' folder
# Files created:
# - Conversation snippets: conv*_len*.html
# - Topic options: conv*_len*option*.html

# %% [markdown]
# # Format conversations in other folders without parsing

# %%
import os
import glob
import pandas as pd
import random

# Configuration
source_folder = "/Users/elisapavarino/Documents/Work_Directory/Kreiman_Lab/Turing Test Paper/TuringGithub/conversation/conversation_task_for_revisions/conversation_24long_AIAI"  # CHANGE THIS: Path to folder containing conv*.html files
excel_file = "esChat.xlsx"  # Path to your Excel file
output_folder = "conversation_24long_AIAI_formatted"  # CHANGE THIS: Path to folder containing conv*.html files

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Read the Excel file
try:
    df = pd.read_excel(excel_file)
    print(f"Successfully loaded Excel file with {len(df)} rows")
    
    # Debug: Show DataFrame info
    print(f"\nDataFrame shape: {df.shape}")
    print(f"\nColumn names:")
    for i, col in enumerate(df.columns):
        print(f"  {i}: '{col}'")
    
    # Check if the expected columns exist
    required_columns = ['conversation_id', 'topic', 'topic_label']
    missing_columns = [col for col in required_columns if col not in df.columns]
    
    if missing_columns:
        print(f"\nERROR: Missing required columns: {missing_columns}")
        print("Please check your Excel file column names.")
        exit(1)
    
except Exception as e:
    print(f"Error loading Excel file: {e}")
    exit(1)

# Get all unique topics (excluding the correct one for each conversation)
all_topics = df['topic'].unique().tolist()
print(f"Found {len(all_topics)} unique topics: {all_topics}")

# Find all conversation files in the source folder
conv_files = glob.glob(os.path.join(source_folder, "conv*.html"))
conv_numbers = []

# Extract conversation numbers from filenames
for file in conv_files:
    filename = os.path.basename(file)
    if filename.startswith("conv") and filename.endswith(".html"):
        try:
            # Extract number from filename like "conv123.html"
            num_str = filename[4:-5]  # Remove "conv" and ".html"
            if num_str.isdigit():
                conv_numbers.append(int(num_str))
        except:
            continue

# Sort conversation numbers
conv_numbers.sort()
print(f"Found conversation files: {conv_numbers}")

# Process each conversation
processed_count = 0
for conv_num in conv_numbers:
    # Find this conversation in the Excel file
    conv_row = df[df['conversation_id'] == conv_num]
    
    if conv_row.empty:
        print(f"Warning: Conversation {conv_num} not found in Excel file, skipping...")
        continue
    
    conv_data = conv_row.iloc[0]
    correct_topic = conv_data['topic']
    topic_label = int(conv_data['topic_label'])  # Which position (1-5) the correct topic should be in
    
    print(f"\nFormatting conversation {conv_num}")
    print(f"  Correct topic: '{correct_topic}' (will be in position {topic_label})")
    
    original_file = os.path.join(source_folder, f'conv{conv_num}.html')
    output_file = os.path.join(output_folder, f'conv{conv_num}.html')
    
    # Check if original conversation file exists
    if not os.path.exists(original_file):
        print(f"Warning: {original_file} not found, skipping...")
        continue
    
    # Generate 4 other topics (excluding the correct one)
    other_topics = [topic for topic in all_topics if topic != correct_topic]
    random.shuffle(other_topics)
    selected_other_topics = other_topics[:4]  # Take first 4 after shuffle
    
    # Create the 5 topics list with correct topic in the right position
    topics_list = [None] * 5
    topics_list[topic_label - 1] = correct_topic  # topic_label is 1-based
    
    # Fill the remaining positions with the other topics
    other_index = 0
    for i in range(5):
        if topics_list[i] is None:
            topics_list[i] = selected_other_topics[other_index]
            other_index += 1
    
    print(f"  Topic options: {topics_list}")
    
    # Create formatted main conversation file
    with open(output_file, "w", encoding='utf-8') as file_html:
        # Write the HTML header with script
        file_html.write("<script>\n")
        file_html.write(" window.addEventListener('load', function() { let message = { height: document.body.scrollHeight, width: document.body.scrollWidth }; window.top.postMessage(message, '*'); }); \n")
        file_html.write(" </script> \n")
        file_html.write(" <font size='3'>\n")
        
        # Read and format the entire conversation
        with open(original_file, 'r', encoding='utf-8') as input_file:
            for line in input_file:
                line = line.strip()
                if line and line.startswith('<p>'):
                    # Extract the content between <p> and </p>
                    # Expected format: <p> A: content </p> or <p> B: content </p>
                    content = line.replace('<p>', '').replace('</p>', '').strip()
                    
                    if content.startswith('A:'):
                        # Speaker A in dark blue
                        formatted_line = f'<FONT COLOR=darkblue><p style="margin-bottom:-18px;">{content}</p> \n</FONT>'
                    elif content.startswith('B:'):
                        # Speaker B in crimson
                        formatted_line = f'<FONT COLOR=crimson><p style="margin-bottom:-18px;">{content}</p> \n</FONT>'
                    else:
                        # Fallback: keep original format but add some styling
                        formatted_line = f'<p style="margin-bottom:-18px;">{content}</p>\n'
                    
                    file_html.write(formatted_line)
                elif line:
                    # Write other non-empty lines as-is
                    file_html.write(line + '\n')
        
        # Close the font tag
        file_html.write("</font>\n")
    
    # Create 5 option files with the topics
    for option_num in range(1, 6):
        option_filename = os.path.join(output_folder, f'conv{conv_num}option{option_num}.html')
        
        with open(option_filename, "w", encoding='utf-8') as option_file:
            option_file.write(topics_list[option_num - 1])
    
    processed_count += 1

print(f"\nFormatting complete!")
print(f"Successfully processed {processed_count} conversations")
print(f"All files created in '{output_folder}' folder")
print("Files created:")
print("- Formatted conversations: conv*.html")
print("- Topic options: conv*option*.html")
# Out:
# Successfully loaded Excel file with 210 rows
#
# DataFrame shape: (210, 17)
#
# Column names:
#   0: 'conversation_id'
#   1: 'Conv_label'
#   2: 'mcq'
#   3: 'A_label'
#   4: 'A_age'
#   5: 'A_gender'
#   6: 'B_label'
#   7: 'B_age'
#   8: 'B_gender'
#   9: 'A_judgeByB'
#   10: 'A_age_judgeByB'
#   11: 'A_gender_judgeByB'
#   12: 'B_judgeByA'
#   13: 'B_age_judgeByA'
#   14: 'B_gender_judgebyA'
#   15: 'topic'
#   16: 'topic_label'
# Found 14 unique topics: ['sports', 'science', 'politics', 'movies', 'fashion', 'music', 'general_entertainment', 'books', 'food', 'technology', 'quarrel', 'traffic', 'emotions', 'ageing']
# Found conversation files: [267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281]
#
# Formatting conversation 267
#   Correct topic: 'food' (will be in position 4)
#   Topic options: ['technology', 'sports', 'ageing', 'food', 'movies']
#
# Formatting conversation 268
#   Correct topic: 'movies' (will be in position 4)
#   Topic options: ['sports', 'ageing', 'quarrel', 'movies', 'emotions']
#
# Formatting conversation 269
#   Correct topic: 'science' (will be in position 4)
#   Topic options: ['technology', 'ageing', 'fashion', 'science', 'movies']
#
# Formatting conversation 270
#   Correct topic: 'fashion' (will be in position 4)
#   Topic options: ['general_entertainment', 'politics', 'sports', 'fashion', 'emotions']
#
# Formatting conversation 271
#   Correct topic: 'ageing' (will be in position 4)
#   Topic options: ['quarrel', 'politics', 'sports', 'ageing', 'general_entertainment']
#
# Formatting conversation 272
#   Correct topic: 'technology' (will be in position 4)
#   Topic options: ['sports', 'books', 'quarrel', 'technology', 'movies']
#
# Formatting conversation 273
#   Correct topic: 'movies' (will be in position 4)
#   Topic options: ['food', 'sports', 'fashion', 'movies', 'books']
#
# Formatting conversation 274
#   Correct topic: 'technology' (will be in position 5)
#   Topic options: ['traffic', 'politics', 'emotions', 'movies', 'technology']
#
# Formatting conversation 275
#   Correct topic: 'movies' (will be in position 5)
#   Topic options: ['general_entertainment', 'politics', 'science', 'fashion', 'movies']
#
# Formatting conversation 276
#   Correct topic: 'food' (will be in position 5)
#   Topic options: ['science', 'music', 'technology', 'quarrel', 'food']
#
# Formatting conversation 277
#   Correct topic: 'books' (will be in position 5)
#   Topic options: ['fashion', 'emotions', 'general_entertainment', 'music', 'books']
#
# Formatting conversation 278
#   Correct topic: 'fashion' (will be in position 5)
#   Topic options: ['music', 'technology', 'sports', 'traffic', 'fashion']
#
# Formatting conversation 279
#   Correct topic: 'food' (will be in position 5)
#   Topic options: ['science', 'books', 'politics', 'technology', 'food']
#
# Formatting conversation 280
#   Correct topic: 'music' (will be in position 5)
#   Topic options: ['sports', 'traffic', 'food', 'movies', 'music']
#
# Formatting conversation 281
#   Correct topic: 'music' (will be in position 5)
#   Topic options: ['quarrel', 'general_entertainment', 'movies', 'sports', 'music']
#
# Formatting complete!
# Successfully processed 15 conversations
# All files created in 'conversation_24long_AIAI_formatted' folder
# Files created:
# - Formatted conversations: conv*.html
# - Topic options: conv*option*.html
