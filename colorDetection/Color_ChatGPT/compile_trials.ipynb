# %%
from google.colab import drive
drive.mount('/content/drive')
ROOT='''/content/drive/MyDrive/Colab Notebooks/googledrive/colorDetection'''
# Out:
# Mounted at /content/drive

# %%
import csv
import json
import sqlite3
import numpy as np
from copy import deepcopy
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from datetime import datetime

# %%
def plot_learning_curve_single_subject(marks_conf,counterbalance):

    fig, ax = plt.subplots(figsize=(5, 3))
    rect = patches.Rectangle((0,-0.2), 3, 1.4, linewidth=1,  facecolor='yellow', alpha=0.5)#edgecolor='r',
    conf_mat = marks_conf[9]
    marks_acc = [(conf_mat.diagonal() / (conf_mat.sum(1)+1e-7)).mean()]
    for i in range(1,6):
        conf_mat = marks_conf[(i+1)*8-1] - marks_conf[i*8-1]
        acc = (conf_mat.diagonal() / (conf_mat.sum(1)+1e-7)).mean()
        marks_acc.append(acc)

    ax.scatter(range(len(marks_acc)),marks_acc,c='black',s=60)

    for i in range(len(marks_acc)-1):
        ax.plot([i,i+1],[marks_acc[i],marks_acc[i+1]],c='black')
    plt.yticks([_*0.1 for _ in range(0,11,2)],[round(_*0.1,1) for _ in range(0,11,2)],fontsize=20)
    plt.xticks(range(len(marks_acc)),[_*8 for _ in range(1,len(marks_acc)+1)],fontsize=20)
    plt.suptitle('counterbalance: {}'.format(counterbalance), fontsize=20)
    # Add the patch to the Axes
    ax.add_patch(rect)
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines[['right', 'left']].set_visible(False)

def construct_confmat():
    labels = ['h_azure','h_histogram','h_google','h_chatgpt']#,'h_catch']
    confmatrices = {**{'h_machine':np.zeros((2,2))}, **{label: np.zeros((1,2)) for label in labels}}
    return confmatrices

def print_metadata(data,dummy_mark='NA'):
    print("====="*20)
    datetime_object1 = datetime.strptime(data[11].split('.')[0], '%Y-%m-%d %H:%M:%S')
    datetime_object2 = datetime.strptime(data[13].split('.')[0], '%Y-%m-%d %H:%M:%S')
    time_used = datetime_object2 - datetime_object1
    time_used = round(time_used.seconds/60,1)
    print("[Finished Date]",datetime_object2)
    print("[Time Used] {} mins".format(time_used))
    print("[Questionnaire]", json.loads(data[-1])["questiondata"])
    print("[Counterbalance]", json.loads(data[-1])["counterbalance"])
    print("[Dummy Test Acc]", dummy_mark)
    return time_used, json.loads(data[-1])["counterbalance"]

def get_gt_from_pagename(pagename):
    # example:  'page_name': '568_e_0.html/',
    return {'a':'Human','b':'Machine','c':'Machine','d':'Machine','e':'Machine'}[pagename.split('_')[1]]

def get_model_from_pagename(pagename):
    # example:  'page_name': '568_e_0.html/',
    return {'b':'azure','c':'histogram','d':'google','e':'chatgpt'}[pagename.split('_')[1]]

conn = sqlite3.connect(ROOT+"/Color_ChatGPT/ec2_db/turing_color_chatgpt.db")
cursor = conn.cursor()
cursor.execute("select * from tablechairDB;")

label_dict = {'H':0,'AI':1,'human':0,'machine':1,'Human':0,'Machine':1,'azure':1,'histogram':1,'google':1,'chatgpt':1}
oneWord_curr_d = {'0':True,'1':False} # dummy test gt
topic_d = {'1':True,'2':False} # user response to dummy tests
modelname_dict = {'catch':'CatchTrial','azure':'Azure','histogram':'Histogram','google':'Google','chatgpt':'ChatGPT'}

count = 0
participant_count = 0
trials_dict = {}
all_data = cursor.fetchall()
completed_counterbalances = []

markers_overall = []
confmat_overall = construct_confmat()
catch_trial_mat_overall = np.zeros((1,2))
swap_trial_mat_overall = np.zeros((1,2))
for i in range(len(all_data)):
    if all_data[i][15] in [5]:
#         print(all_data[i][11])
        data_dict = json.loads(all_data[i][17])
        if data_dict['mode'] != 'live':
            continue
        # filter out subjects using dummy trial accuracy
        # original threshold in the paper: 7/12
        dummy_mark = 0
        nTrials = 40
        threshold = nTrials*(7/12) # change to number of total trials
        for dat in data_dict['data']:

            if dat['trialdata']['phase'] == 'TEST':
                present = dat['trialdata']['oneWord_curr'] == '0'
                response_present = dat['trialdata']['topic'] == '1'
                if present == response_present:
                    dummy_mark += 1
        if dummy_mark < threshold:
            continue
        markers_overall.append(dummy_mark)

        # construct conf matrices
        time_used, counterbalance = print_metadata(all_data[i],"{}/{}".format(dummy_mark,nTrials))
        completed_counterbalances.append(counterbalance)
#         marks = []
#         marks_conf = []
        confmatrices = construct_confmat() # without catch
        catch_trial_mat = np.zeros((1,2))
        swap_trial_mat = np.zeros((1,2))
        marks = []
        marks_conf = []
        participant_count += 1
        nTrial = 0


        for dat in data_dict['data']:
            if dat['trialdata']['phase'] == 'TEST':

                nTrial+=1
                trial_data = {}
                trial_data['workerID'] = data_dict['workerId']
                trial_data['workerData'] = data_dict['questiondata']
                trial_data['trialData'] = dat['trialdata']


#                 trials_dict['Trial_'+str(count)] = trial_data
#                 trial_data = trial_data['trialData']
                trial_data['trialData']['correct response'] = get_gt_from_pagename(trial_data['trialData']['page_name'])
                trial_data['trialData']['choose response'] = trial_data['trialData']['Aclass']

#                 print(trial_data)
                if trial_data['trialData']['correct response'] == 'Catch':
                    catch_trial_mat[0][label_dict[trial_data['trialData']['choose response']]] += 1
                    catch_trial_mat_overall[0][label_dict[trial_data['trialData']['choose response']]] += 1
                elif trial_data['trialData']['correct response'] == 'Swapped':
                    swap_trial_mat[0][label_dict[trial_data['trialData']['choose response']]] += 1
                    swap_trial_mat_overall[0][label_dict[trial_data['trialData']['choose response']]] += 1
                else:
                    confmatrices['h_machine'][label_dict[trial_data['trialData']['correct response']]][label_dict[trial_data['trialData']['choose response']]] += 1
                    confmat_overall['h_machine'][label_dict[trial_data['trialData']['correct response']]][label_dict[trial_data['trialData']['choose response']]] += 1
                    if trial_data['trialData']['correct response'] == "Machine":
                        model = get_model_from_pagename(trial_data['trialData']['page_name'])
                        confmatrices['h_{}'.format(model)][0][label_dict[trial_data['trialData']['choose response']]] += 1
                        confmat_overall['h_{}'.format(model)][0][label_dict[trial_data['trialData']['choose response']]] += 1
                    marks.append(1 if trial_data['trialData']['correct response'] == trial_data['trialData']['choose response'] else 0)
                    marks_conf.append(deepcopy(confmatrices['h_machine']))

#                 trial_data['trialData'] = dat['trialdata']
                if trial_data['trialData']['correct response']  in ['Catch','Swapped']:
                    continue

                count += 1
                trial_data['trialData']['response_gender'] = trial_data['trialData']['Agender']
                del trial_data['trialData']['Agender']

                trial_data['trialData']['response_speaker'] = {'h':'human','ai':'machine'}[trial_data['trialData']['choose response'].lower()]
                del trial_data['trialData']['choose response']

                trial_data['trialData']['response_object'] = trial_data['trialData']['topic'].lower()
                del trial_data['trialData']['topic']

                trial_data['trialData']['groundtruth'] = trial_data['trialData']['correct response'].lower()


                trial_data['trialData']['object_groundtruth'] = trial_data['trialData']['oneWord_curr'].lower()
                del trial_data['trialData']['oneWord_curr']

                if trial_data['trialData']['correct response'] in ["Machine","Catch","Swapped"]:
                    trial_data['trialData']['machine_groundtruth'] = modelname_dict[model.lower()]
                else:
                    trial_data['trialData']['machine_groundtruth'] = ''

                del trial_data['trialData']['correct response']
#                 trial_data['trialData']["imgtype"] = "naturaldesign"



                trials_dict['Trial_Color_'+str(count)] = trial_data

#         plot_learning_curve_single_subject(marks_conf,participant_count)
        print(confmatrices)
        print('catch',catch_trial_mat)
#         print('swap',swap_trial_mat)
#     else:
#         print(all_data[i][15])
conn.close()
# Out:
# ====================================================================================================
# [Finished Date] 2025-04-22 10:46:42
# [Time Used] 8.1 mins
# [Questionnaire] {'country': 'United Kingdom', 'age': '51', 'engagement': '10', 'difficulty': '8', 'mode': 'live', 'gender': 'female', 'education': 'high school', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 37/40
# {'h_machine': array([[ 6., 14.],
#        [10., 10.]]), 'h_azure': array([[3., 2.]]), 'h_histogram': array([[2., 3.]]), 'h_google': array([[1., 4.]]), 'h_chatgpt': array([[4., 1.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 10:44:54
# [Time Used] 3.9 mins
# [Questionnaire] {'country': 'United States', 'age': '41-45', 'engagement': '8', 'difficulty': '2', 'mode': 'live', 'gender': 'female', 'education': 'high school', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 32/40
# {'h_machine': array([[12.,  8.],
#        [ 8., 12.]]), 'h_azure': array([[1., 4.]]), 'h_histogram': array([[1., 4.]]), 'h_google': array([[3., 2.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 10:51:20
# [Time Used] 8.7 mins
# [Questionnaire] {'country': 'United States', 'age': '36-40', 'engagement': '9', 'difficulty': '3', 'mode': 'live', 'gender': 'male', 'education': 'bachelor', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 36/40
# {'h_machine': array([[14.,  6.],
#        [12.,  8.]]), 'h_azure': array([[2., 3.]]), 'h_histogram': array([[3., 2.]]), 'h_google': array([[2., 3.]]), 'h_chatgpt': array([[5., 0.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 10:46:50
# [Time Used] 3.5 mins
# [Questionnaire] {'country': 'United States', 'age': '45-50', 'engagement': '10', 'difficulty': '0', 'mode': 'live', 'gender': 'male', 'education': 'high school', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 31/40
# {'h_machine': array([[13.,  7.],
#        [ 9., 11.]]), 'h_azure': array([[2., 3.]]), 'h_histogram': array([[3., 2.]]), 'h_google': array([[1., 4.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 11:00:21
# [Time Used] 5.2 mins
# [Questionnaire] {'country': 'United States', 'age': '51', 'engagement': '7', 'difficulty': '5', 'mode': 'live', 'gender': 'male', 'education': 'bachelor', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 35/40
# {'h_machine': array([[14.,  6.],
#        [ 7., 13.]]), 'h_azure': array([[1., 4.]]), 'h_histogram': array([[2., 3.]]), 'h_google': array([[0., 5.]]), 'h_chatgpt': array([[4., 1.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 11:07:24
# [Time Used] 5.7 mins
# [Questionnaire] {'country': 'United States', 'age': '45-50', 'engagement': '5', 'difficulty': '2', 'mode': 'live', 'gender': 'non_binary', 'education': 'high school', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 35/40
# {'h_machine': array([[17.,  3.],
#        [10., 10.]]), 'h_azure': array([[3., 2.]]), 'h_histogram': array([[2., 3.]]), 'h_google': array([[2., 3.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 11:20:06
# [Time Used] 14.5 mins
# [Questionnaire] {'country': 'United States', 'age': '51', 'engagement': '5', 'difficulty': '5', 'mode': 'live', 'gender': 'female', 'education': 'high school', 'ai-experience': '0', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 35/40
# {'h_machine': array([[15.,  5.],
#        [10., 10.]]), 'h_azure': array([[2., 3.]]), 'h_histogram': array([[1., 4.]]), 'h_google': array([[3., 2.]]), 'h_chatgpt': array([[4., 1.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 11:31:28
# [Time Used] 15.7 mins
# [Questionnaire] {'country': 'United States', 'age': '45-50', 'engagement': '9', 'difficulty': '4', 'mode': 'live', 'gender': 'female', 'education': 'high school', 'ai-experience': '3', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 33/40
# {'h_machine': array([[10., 10.],
#        [ 5., 15.]]), 'h_azure': array([[3., 2.]]), 'h_histogram': array([[1., 4.]]), 'h_google': array([[0., 5.]]), 'h_chatgpt': array([[1., 4.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 11:25:25
# [Time Used] 7.2 mins
# [Questionnaire] {'country': 'Bosnia and Herzegovina', 'age': '51', 'engagement': '10', 'difficulty': '7', 'mode': 'live', 'gender': 'female', 'education': 'high school', 'ai-experience': '3', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 35/40
# {'h_machine': array([[ 9., 11.],
#        [ 7., 13.]]), 'h_azure': array([[2., 3.]]), 'h_histogram': array([[2., 3.]]), 'h_google': array([[0., 5.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 11:32:53
# [Time Used] 13.8 mins
# [Questionnaire] {'country': 'United States', 'age': '51', 'engagement': '5', 'difficulty': '7', 'mode': 'live', 'gender': 'female', 'education': 'high school', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 36/40
# {'h_machine': array([[ 5., 15.],
#        [ 6., 14.]]), 'h_azure': array([[3., 2.]]), 'h_histogram': array([[1., 4.]]), 'h_google': array([[0., 5.]]), 'h_chatgpt': array([[2., 3.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 12:14:49
# [Time Used] 13.8 mins
# [Questionnaire] {'country': 'United States', 'age': '45-50', 'engagement': '3', 'difficulty': '3', 'mode': 'live', 'gender': 'male', 'education': 'high school', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 38/40
# {'h_machine': array([[15.,  5.],
#        [ 7., 13.]]), 'h_azure': array([[3., 2.]]), 'h_histogram': array([[1., 4.]]), 'h_google': array([[0., 5.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 12:38:41
# [Time Used] 12.3 mins
# [Questionnaire] {'country': 'United States', 'age': '36-40', 'engagement': '9', 'difficulty': '6', 'mode': 'live', 'gender': 'male', 'education': 'bachelor', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 34/40
# {'h_machine': array([[10., 10.],
#        [ 7., 13.]]), 'h_azure': array([[3., 2.]]), 'h_histogram': array([[0., 5.]]), 'h_google': array([[1., 4.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 12:44:21
# [Time Used] 5.4 mins
# [Questionnaire] {'country': 'United States', 'age': '36-40', 'engagement': '9', 'difficulty': '2', 'mode': 'live', 'gender': 'female', 'education': 'high school', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 38/40
# {'h_machine': array([[14.,  6.],
#        [ 6., 14.]]), 'h_azure': array([[1., 4.]]), 'h_histogram': array([[1., 4.]]), 'h_google': array([[1., 4.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 12:46:59
# [Time Used] 6.7 mins
# [Questionnaire] {'country': 'United States', 'age': '45-50', 'engagement': '10', 'difficulty': '6', 'mode': 'live', 'gender': 'male', 'education': 'bachelor', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 39/40
# {'h_machine': array([[17.,  3.],
#        [ 9., 11.]]), 'h_azure': array([[1., 4.]]), 'h_histogram': array([[1., 4.]]), 'h_google': array([[3., 2.]]), 'h_chatgpt': array([[4., 1.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 13:26:09
# [Time Used] 6.7 mins
# [Questionnaire] {'country': 'United States', 'age': '31-35', 'engagement': '8', 'difficulty': '7', 'mode': 'live', 'gender': 'female', 'education': 'bachelor', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 34/40
# {'h_machine': array([[14.,  6.],
#        [11.,  9.]]), 'h_azure': array([[3., 2.]]), 'h_histogram': array([[3., 2.]]), 'h_google': array([[1., 4.]]), 'h_chatgpt': array([[4., 1.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 13:51:51
# [Time Used] 8.9 mins
# [Questionnaire] {'country': 'United States', 'age': '51', 'engagement': '3', 'difficulty': '5', 'mode': 'live', 'gender': 'male', 'education': 'bachelor', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 35/40
# {'h_machine': array([[ 7., 13.],
#        [ 8., 12.]]), 'h_azure': array([[2., 3.]]), 'h_histogram': array([[3., 2.]]), 'h_google': array([[2., 3.]]), 'h_chatgpt': array([[1., 4.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 13:49:17
# [Time Used] 6.3 mins
# [Questionnaire] {'country': 'United States', 'age': '41-45', 'engagement': '10', 'difficulty': '5', 'mode': 'live', 'gender': 'male', 'education': 'master', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 30/40
# {'h_machine': array([[16.,  4.],
#        [11.,  9.]]), 'h_azure': array([[1., 4.]]), 'h_histogram': array([[4., 1.]]), 'h_google': array([[2., 3.]]), 'h_chatgpt': array([[4., 1.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 13:57:14
# [Time Used] 7.3 mins
# [Questionnaire] {'country': 'United States', 'age': '36-40', 'engagement': '8', 'difficulty': '3', 'mode': 'live', 'gender': 'male', 'education': 'high school', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 35/40
# {'h_machine': array([[11.,  9.],
#        [10., 10.]]), 'h_azure': array([[3., 2.]]), 'h_histogram': array([[1., 4.]]), 'h_google': array([[3., 2.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 14:10:36
# [Time Used] 11.4 mins
# [Questionnaire] {'country': 'United States', 'age': '51', 'engagement': '7', 'difficulty': '7', 'mode': 'live', 'gender': 'male', 'education': 'bachelor', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 37/40
# {'h_machine': array([[15.,  5.],
#        [ 7., 13.]]), 'h_azure': array([[1., 4.]]), 'h_histogram': array([[1., 4.]]), 'h_google': array([[2., 3.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 14:40:44
# [Time Used] 7.8 mins
# [Questionnaire] {'country': 'United States', 'age': '45-50', 'engagement': '10', 'difficulty': '7', 'mode': 'live', 'gender': 'male', 'education': 'high school', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 34/40
# {'h_machine': array([[ 9., 11.],
#        [ 3., 17.]]), 'h_azure': array([[0., 5.]]), 'h_histogram': array([[1., 4.]]), 'h_google': array([[0., 5.]]), 'h_chatgpt': array([[2., 3.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 15:00:01
# [Time Used] 13.5 mins
# [Questionnaire] {'country': 'United States', 'age': '26-30', 'engagement': '10', 'difficulty': '8', 'mode': 'live', 'gender': 'male', 'education': 'master', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 34/40
# {'h_machine': array([[ 9., 11.],
#        [13.,  7.]]), 'h_azure': array([[2., 3.]]), 'h_histogram': array([[3., 2.]]), 'h_google': array([[4., 1.]]), 'h_chatgpt': array([[4., 1.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 15:27:22
# [Time Used] 8.1 mins
# [Questionnaire] {'country': 'United States', 'age': '51', 'engagement': '10', 'difficulty': '5', 'mode': 'live', 'gender': 'female', 'education': 'high school', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 37/40
# {'h_machine': array([[10., 10.],
#        [10., 10.]]), 'h_azure': array([[1., 4.]]), 'h_histogram': array([[3., 2.]]), 'h_google': array([[3., 2.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 15:31:50
# [Time Used] 6.5 mins
# [Questionnaire] {'country': 'United States', 'age': '51', 'engagement': '5', 'difficulty': '4', 'mode': 'live', 'gender': 'female', 'education': 'pg', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 36/40
# {'h_machine': array([[ 0., 20.],
#        [ 0., 20.]]), 'h_azure': array([[0., 5.]]), 'h_histogram': array([[0., 5.]]), 'h_google': array([[0., 5.]]), 'h_chatgpt': array([[0., 5.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 15:41:54
# [Time Used] 8.4 mins
# [Questionnaire] {'country': 'United States', 'age': '31-35', 'engagement': '10', 'difficulty': '9', 'mode': 'live', 'gender': 'female', 'education': 'high school', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 37/40
# {'h_machine': array([[ 9., 11.],
#        [ 9., 11.]]), 'h_azure': array([[2., 3.]]), 'h_histogram': array([[1., 4.]]), 'h_google': array([[1., 4.]]), 'h_chatgpt': array([[5., 0.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 15:55:01
# [Time Used] 5.3 mins
# [Questionnaire] {'country': 'United States', 'age': '36-40', 'engagement': '9', 'difficulty': '10', 'mode': 'live', 'gender': 'male', 'education': 'bachelor', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 36/40
# {'h_machine': array([[11.,  9.],
#        [ 6., 14.]]), 'h_azure': array([[1., 4.]]), 'h_histogram': array([[1., 4.]]), 'h_google': array([[1., 4.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 16:05:27
# [Time Used] 3.5 mins
# [Questionnaire] {'country': 'United States', 'age': '31-35', 'engagement': '8', 'difficulty': '9', 'mode': 'live', 'gender': 'female', 'education': 'high school', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 39/40
# {'h_machine': array([[ 9., 11.],
#        [ 5., 15.]]), 'h_azure': array([[1., 4.]]), 'h_histogram': array([[0., 5.]]), 'h_google': array([[2., 3.]]), 'h_chatgpt': array([[2., 3.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 16:13:38
# [Time Used] 6.3 mins
# [Questionnaire] {'country': 'United States', 'age': '41-45', 'engagement': '10', 'difficulty': '5', 'mode': 'live', 'gender': 'female', 'education': 'bachelor', 'ai-experience': '3', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 37/40
# {'h_machine': array([[13.,  7.],
#        [ 7., 13.]]), 'h_azure': array([[1., 4.]]), 'h_histogram': array([[1., 4.]]), 'h_google': array([[1., 4.]]), 'h_chatgpt': array([[4., 1.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 16:18:59
# [Time Used] 8.1 mins
# [Questionnaire] {'country': 'United States', 'age': '45-50', 'engagement': '7', 'difficulty': '10', 'mode': 'live', 'gender': 'female', 'education': 'bachelor', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 39/40
# {'h_machine': array([[ 4., 16.],
#        [ 8., 12.]]), 'h_azure': array([[2., 3.]]), 'h_histogram': array([[0., 5.]]), 'h_google': array([[3., 2.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 16:33:00
# [Time Used] 7.0 mins
# [Questionnaire] {'country': 'United States', 'age': '36-40', 'engagement': '3', 'difficulty': '5', 'mode': 'live', 'gender': 'male', 'education': 'bachelor', 'ai-experience': '3', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 34/40
# {'h_machine': array([[14.,  6.],
#        [15.,  5.]]), 'h_azure': array([[3., 2.]]), 'h_histogram': array([[2., 3.]]), 'h_google': array([[5., 0.]]), 'h_chatgpt': array([[5., 0.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 16:36:42
# [Time Used] 8.1 mins
# [Questionnaire] {'country': 'United States', 'age': '31-35', 'engagement': '9', 'difficulty': '8', 'mode': 'live', 'gender': 'male', 'education': 'high school', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 38/40
# {'h_machine': array([[ 9., 11.],
#        [ 6., 14.]]), 'h_azure': array([[1., 4.]]), 'h_histogram': array([[2., 3.]]), 'h_google': array([[0., 5.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 16:42:38
# [Time Used] 9.2 mins
# [Questionnaire] {'country': 'United States', 'age': '41-45', 'engagement': '6', 'difficulty': '7', 'mode': 'live', 'gender': 'male', 'education': 'bachelor', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 35/40
# {'h_machine': array([[11.,  9.],
#        [11.,  9.]]), 'h_azure': array([[3., 2.]]), 'h_histogram': array([[2., 3.]]), 'h_google': array([[3., 2.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 17:01:02
# [Time Used] 7.2 mins
# [Questionnaire] {'country': 'United States', 'age': '31-35', 'engagement': '9', 'difficulty': '1', 'mode': 'live', 'gender': 'male', 'education': 'bachelor', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 33/40
# {'h_machine': array([[15.,  5.],
#        [ 9., 11.]]), 'h_azure': array([[3., 2.]]), 'h_histogram': array([[2., 3.]]), 'h_google': array([[3., 2.]]), 'h_chatgpt': array([[1., 4.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 17:00:10
# [Time Used] 6.2 mins
# [Questionnaire] {'country': 'United States', 'age': '31-35', 'engagement': '5', 'difficulty': '5', 'mode': 'live', 'gender': 'female', 'education': 'bachelor', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 33/40
# {'h_machine': array([[12.,  8.],
#        [ 9., 11.]]), 'h_azure': array([[3., 2.]]), 'h_histogram': array([[0., 5.]]), 'h_google': array([[2., 3.]]), 'h_chatgpt': array([[4., 1.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 17:29:02
# [Time Used] 6.1 mins
# [Questionnaire] {'country': 'United States', 'age': '26-30', 'engagement': '6', 'difficulty': '6', 'mode': 'live', 'gender': 'male', 'education': 'bachelor', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 36/40
# {'h_machine': array([[10., 10.],
#        [ 7., 13.]]), 'h_azure': array([[1., 4.]]), 'h_histogram': array([[3., 2.]]), 'h_google': array([[1., 4.]]), 'h_chatgpt': array([[2., 3.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 17:43:53
# [Time Used] 8.7 mins
# [Questionnaire] {'country': 'United States', 'age': '51', 'engagement': '6', 'difficulty': '7', 'mode': 'live', 'gender': 'female', 'education': 'bachelor', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 31/40
# {'h_machine': array([[14.,  6.],
#        [ 8., 12.]]), 'h_azure': array([[1., 4.]]), 'h_histogram': array([[0., 5.]]), 'h_google': array([[2., 3.]]), 'h_chatgpt': array([[5., 0.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 18:23:59
# [Time Used] 9.3 mins
# [Questionnaire] {'country': 'United States', 'age': '31-35', 'engagement': '10', 'difficulty': '2', 'mode': 'live', 'gender': 'male', 'education': 'bachelor', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 36/40
# {'h_machine': array([[14.,  6.],
#        [ 9., 11.]]), 'h_azure': array([[1., 4.]]), 'h_histogram': array([[3., 2.]]), 'h_google': array([[2., 3.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 18:32:14
# [Time Used] 4.8 mins
# [Questionnaire] {'country': 'United States', 'age': '41-45', 'engagement': '10', 'difficulty': '1', 'mode': 'live', 'gender': 'female', 'education': 'bachelor', 'ai-experience': '0', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 35/40
# {'h_machine': array([[ 7., 13.],
#        [ 8., 12.]]), 'h_azure': array([[1., 4.]]), 'h_histogram': array([[2., 3.]]), 'h_google': array([[3., 2.]]), 'h_chatgpt': array([[2., 3.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 18:44:08
# [Time Used] 4.2 mins
# [Questionnaire] {'country': 'United States', 'age': '45-50', 'engagement': '10', 'difficulty': '1', 'mode': 'live', 'gender': 'male', 'education': 'high school', 'ai-experience': '3', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 34/40
# {'h_machine': array([[10., 10.],
#        [ 8., 12.]]), 'h_azure': array([[3., 2.]]), 'h_histogram': array([[2., 3.]]), 'h_google': array([[0., 5.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 19:08:53
# [Time Used] 5.8 mins
# [Questionnaire] {'country': 'United States', 'age': '41-45', 'engagement': '6', 'difficulty': '6', 'mode': 'live', 'gender': 'female', 'education': 'high school', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 36/40
# {'h_machine': array([[ 6., 14.],
#        [ 8., 12.]]), 'h_azure': array([[2., 3.]]), 'h_histogram': array([[1., 4.]]), 'h_google': array([[2., 3.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 19:19:48
# [Time Used] 8.9 mins
# [Questionnaire] {'country': 'United States', 'age': '36-40', 'engagement': '10', 'difficulty': '7', 'mode': 'live', 'gender': 'female', 'education': 'bachelor', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 36/40
# {'h_machine': array([[11.,  9.],
#        [ 8., 12.]]), 'h_azure': array([[1., 4.]]), 'h_histogram': array([[1., 4.]]), 'h_google': array([[2., 3.]]), 'h_chatgpt': array([[4., 1.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 19:23:39
# [Time Used] 10.6 mins
# [Questionnaire] {'country': 'United States', 'age': '36-40', 'engagement': '6', 'difficulty': '4', 'mode': 'live', 'gender': 'female', 'education': 'bachelor', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 32/40
# {'h_machine': array([[12.,  8.],
#        [ 9., 11.]]), 'h_azure': array([[1., 4.]]), 'h_histogram': array([[1., 4.]]), 'h_google': array([[4., 1.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 19:24:47
# [Time Used] 8.1 mins
# [Questionnaire] {'country': 'United States', 'age': '51', 'engagement': '8', 'difficulty': '5', 'mode': 'live', 'gender': 'male', 'education': 'high school', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 37/40
# {'h_machine': array([[10., 10.],
#        [ 6., 14.]]), 'h_azure': array([[0., 5.]]), 'h_histogram': array([[0., 5.]]), 'h_google': array([[2., 3.]]), 'h_chatgpt': array([[4., 1.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 19:26:36
# [Time Used] 9.6 mins
# [Questionnaire] {'country': 'United States', 'age': '41-45', 'engagement': '4', 'difficulty': '3', 'mode': 'live', 'gender': 'female', 'education': 'high school', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 38/40
# {'h_machine': array([[ 9., 11.],
#        [ 7., 13.]]), 'h_azure': array([[3., 2.]]), 'h_histogram': array([[0., 5.]]), 'h_google': array([[1., 4.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 19:25:19
# [Time Used] 7.9 mins
# [Questionnaire] {'country': 'United States', 'age': '45-50', 'engagement': '5', 'difficulty': '9', 'mode': 'live', 'gender': 'female', 'education': 'bachelor', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 39/40
# {'h_machine': array([[18.,  2.],
#        [10., 10.]]), 'h_azure': array([[0., 5.]]), 'h_histogram': array([[3., 2.]]), 'h_google': array([[3., 2.]]), 'h_chatgpt': array([[4., 1.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 19:46:12
# [Time Used] 12.2 mins
# [Questionnaire] {'country': 'United States', 'age': '51', 'engagement': '4', 'difficulty': '3', 'mode': 'live', 'gender': 'female', 'education': 'bachelor', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 39/40
# {'h_machine': array([[ 7., 13.],
#        [ 5., 15.]]), 'h_azure': array([[2., 3.]]), 'h_histogram': array([[0., 5.]]), 'h_google': array([[1., 4.]]), 'h_chatgpt': array([[2., 3.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 19:44:43
# [Time Used] 6.0 mins
# [Questionnaire] {'country': 'United States', 'age': '51', 'engagement': '8', 'difficulty': '4', 'mode': 'live', 'gender': 'female', 'education': 'bachelor', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 34/40
# {'h_machine': array([[ 8., 12.],
#        [ 7., 13.]]), 'h_azure': array([[2., 3.]]), 'h_histogram': array([[1., 4.]]), 'h_google': array([[1., 4.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 20:03:20
# [Time Used] 10.8 mins
# [Questionnaire] {'country': 'United States', 'age': '36-40', 'engagement': '9', 'difficulty': '3', 'mode': 'live', 'gender': 'male', 'education': 'bachelor', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 39/40
# {'h_machine': array([[13.,  7.],
#        [10., 10.]]), 'h_azure': array([[3., 2.]]), 'h_histogram': array([[2., 3.]]), 'h_google': array([[2., 3.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 20:02:55
# [Time Used] 5.7 mins
# [Questionnaire] {'country': 'United States', 'age': '51', 'engagement': '10', 'difficulty': '3', 'mode': 'live', 'gender': 'female', 'education': 'bachelor', 'ai-experience': '3', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 38/40
# {'h_machine': array([[10., 10.],
#        [ 6., 14.]]), 'h_azure': array([[2., 3.]]), 'h_histogram': array([[0., 5.]]), 'h_google': array([[1., 4.]]), 'h_chatgpt': array([[3., 2.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 20:36:09
# [Time Used] 10.3 mins
# [Questionnaire] {'country': 'United States', 'age': '51', 'engagement': '6', 'difficulty': '4', 'mode': 'live', 'gender': 'male', 'education': 'master', 'ai-experience': '1', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 35/40
# {'h_machine': array([[ 7., 13.],
#        [ 8., 12.]]), 'h_azure': array([[3., 2.]]), 'h_histogram': array([[2., 3.]]), 'h_google': array([[1., 4.]]), 'h_chatgpt': array([[2., 3.]])}
# catch [[0. 0.]]
# ====================================================================================================
# [Finished Date] 2025-04-22 20:40:14
# [Time Used] 7.2 mins
# [Questionnaire] {'country': 'United States', 'age': '51', 'engagement': '6', 'difficulty': '4', 'mode': 'live', 'gender': 'female', 'education': 'bachelor', 'ai-experience': '2', 'condition': 0, 'native': 'yes'}
# [Counterbalance] 0
# [Dummy Test Acc] 32/40
# {'h_machine': array([[10., 10.],
#        [13.,  7.]]), 'h_azure': array([[4., 1.]]), 'h_histogram': array([[3., 2.]]), 'h_google': array([[2., 3.]]), 'h_chatgpt': array([[4., 1.]])}
# catch [[0. 0.]]

# %%
with open("/home/liuxiao/TuringGithubRunnable/dominant_color_recognition/Plot/Data_all/humanjudge_Color_ChatGPT_testphase.json", 'w') as f:
    json.dump(trials_dict,f)

# %%
len(trials_dict)
# Out:
# 2000

# %%
confmat_overall
# Out:
# {'h_machine': array([[545., 455.],
#         [408., 592.]]),
#  'h_azure': array([[ 93., 157.]]),
#  'h_histogram': array([[ 75., 175.]]),
#  'h_google': array([[ 85., 165.]]),
#  'h_chatgpt': array([[155.,  95.]])}

# %%
np.mean(markers_overall)/40
# Out:
# np.float64(0.8869999999999999)

# %%
trials_dict
# Out:
# {'Trial_Color_1': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 14236,
#    'Aclass': 'H',
#    'hit': '1',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/553.jpg',
#    'trial': 1,
#    'page_name': '553_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_2': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 10297,
#    'Aclass': 'AI',
#    'hit': '10',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/565.jpg',
#    'trial': 2,
#    'page_name': '565_d_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Google'}},
#  'Trial_Color_3': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 7656,
#    'Aclass': 'H',
#    'hit': '100',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/16.jpg',
#    'trial': 3,
#    'page_name': '16_c_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Histogram'}},
#  'Trial_Color_4': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 8240,
#    'Aclass': 'AI',
#    'hit': '1000',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/1175.jpg',
#    'trial': 4,
#    'page_name': '1175_e_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'ChatGPT'}},
#  'Trial_Color_5': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 11588,
#    'Aclass': 'H',
#    'hit': '1001',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/682.jpg',
#    'trial': 5,
#    'page_name': '682_e_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'ChatGPT'}},
#  'Trial_Color_6': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 7023,
#    'Aclass': 'AI',
#    'hit': '1003',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/273.jpg',
#    'trial': 6,
#    'page_name': '273_b_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'Azure'}},
#  'Trial_Color_7': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 8544,
#    'Aclass': 'H',
#    'hit': '1004',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/418.jpg',
#    'trial': 7,
#    'page_name': '418_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_8': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 6862,
#    'Aclass': 'AI',
#    'hit': '1006',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/1195.jpg',
#    'trial': 8,
#    'page_name': '1195_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_9': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 11532,
#    'Aclass': 'AI',
#    'hit': '1007',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/404.jpg',
#    'trial': 9,
#    'page_name': '404_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_10': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 7585,
#    'Aclass': 'H',
#    'hit': '1008',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/263.jpg',
#    'trial': 10,
#    'page_name': '263_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_11': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 7706,
#    'Aclass': 'AI',
#    'hit': '1010',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/483.jpg',
#    'trial': 11,
#    'page_name': '483_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_12': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 6164,
#    'Aclass': 'AI',
#    'hit': '1011',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/297.jpg',
#    'trial': 12,
#    'page_name': '297_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_13': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 32730,
#    'Aclass': 'AI',
#    'hit': '1012',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/357.jpg',
#    'trial': 13,
#    'page_name': '357_d_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Google'}},
#  'Trial_Color_14': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 8667,
#    'Aclass': 'AI',
#    'hit': '1014',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/186.jpg',
#    'trial': 14,
#    'page_name': '186_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_15': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 7552,
#    'Aclass': 'H',
#    'hit': '1015',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/143.jpg',
#    'trial': 15,
#    'page_name': '143_e_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'ChatGPT'}},
#  'Trial_Color_16': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 7443,
#    'Aclass': 'H',
#    'hit': '1017',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/768.jpg',
#    'trial': 16,
#    'page_name': '768_e_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'ChatGPT'}},
#  'Trial_Color_17': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 8592,
#    'Aclass': 'AI',
#    'hit': '1019',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/647.jpg',
#    'trial': 17,
#    'page_name': '647_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_18': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 7382,
#    'Aclass': 'AI',
#    'hit': '102',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/1095.jpg',
#    'trial': 18,
#    'page_name': '1095_d_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Google'}},
#  'Trial_Color_19': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 10549,
#    'Aclass': 'AI',
#    'hit': '1020',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/989.jpg',
#    'trial': 19,
#    'page_name': '989_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_20': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 8584,
#    'Aclass': 'H',
#    'hit': '1022',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/244.jpg',
#    'trial': 20,
#    'page_name': '244_b_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Azure'}},
#  'Trial_Color_21': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 6213,
#    'Aclass': 'AI',
#    'hit': '1024',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/1030.jpg',
#    'trial': 21,
#    'page_name': '1030_c_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Histogram'}},
#  'Trial_Color_22': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 9036,
#    'Aclass': 'H',
#    'hit': '1025',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/62.jpg',
#    'trial': 22,
#    'page_name': '62_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_23': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 8840,
#    'Aclass': 'AI',
#    'hit': '1026',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/313.jpg',
#    'trial': 23,
#    'page_name': '313_b_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'Azure'}},
#  'Trial_Color_24': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 7576,
#    'Aclass': 'AI',
#    'hit': '1027',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/952.jpg',
#    'trial': 24,
#    'page_name': '952_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_25': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 6272,
#    'Aclass': 'AI',
#    'hit': '1028',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/627.jpg',
#    'trial': 25,
#    'page_name': '627_c_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Histogram'}},
#  'Trial_Color_26': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 6510,
#    'Aclass': 'H',
#    'hit': '103',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/316.jpg',
#    'trial': 26,
#    'page_name': '316_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_27': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 9116,
#    'Aclass': 'H',
#    'hit': '1030',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/1060.jpg',
#    'trial': 27,
#    'page_name': '1060_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_28': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 5715,
#    'Aclass': 'AI',
#    'hit': '1031',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/375.jpg',
#    'trial': 28,
#    'page_name': '375_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_29': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 6338,
#    'Aclass': 'AI',
#    'hit': '1032',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/608.jpg',
#    'trial': 29,
#    'page_name': '608_d_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'Google'}},
#  'Trial_Color_30': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 7213,
#    'Aclass': 'AI',
#    'hit': '1034',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/329.jpg',
#    'trial': 30,
#    'page_name': '329_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_31': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 7256,
#    'Aclass': 'AI',
#    'hit': '1036',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/539.jpg',
#    'trial': 31,
#    'page_name': '539_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_32': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 5978,
#    'Aclass': 'H',
#    'hit': '1039',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/684.jpg',
#    'trial': 32,
#    'page_name': '684_b_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'Azure'}},
#  'Trial_Color_33': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 10731,
#    'Aclass': 'H',
#    'hit': '1040',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/408.jpg',
#    'trial': 33,
#    'page_name': '408_b_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Azure'}},
#  'Trial_Color_34': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 51239,
#    'Aclass': 'H',
#    'hit': '1042',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/420.jpg',
#    'trial': 34,
#    'page_name': '420_e_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'ChatGPT'}},
#  'Trial_Color_35': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 7683,
#    'Aclass': 'AI',
#    'hit': '1043',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/420.jpg',
#    'trial': 35,
#    'page_name': '420_c_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Histogram'}},
#  'Trial_Color_36': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 7985,
#    'Aclass': 'H',
#    'hit': '1044',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/445.jpg',
#    'trial': 36,
#    'page_name': '445_d_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Google'}},
#  'Trial_Color_37': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 6936,
#    'Aclass': 'AI',
#    'hit': '1045',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/134.jpg',
#    'trial': 37,
#    'page_name': '134_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_38': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 7397,
#    'Aclass': 'H',
#    'hit': '1047',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/1141.jpg',
#    'trial': 38,
#    'page_name': '1141_c_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Histogram'}},
#  'Trial_Color_39': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 6896,
#    'Aclass': 'AI',
#    'hit': '1048',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/848.jpg',
#    'trial': 39,
#    'page_name': '848_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_40': {'workerID': 'A1FVXS8IM5QYO8',
#   'workerData': {'country': 'United Kingdom',
#    'age': '51',
#    'engagement': '10',
#    'difficulty': '8',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 15233,
#    'Aclass': 'AI',
#    'hit': '1049',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/126.jpg',
#    'trial': 40,
#    'page_name': '126_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_41': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 9933,
#    'Aclass': 'H',
#    'hit': '1',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/310.jpg',
#    'trial': 1,
#    'page_name': '310_e_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'ChatGPT'}},
#  'Trial_Color_42': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3914,
#    'Aclass': 'H',
#    'hit': '10',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/1178.jpg',
#    'trial': 2,
#    'page_name': '1178_c_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Histogram'}},
#  'Trial_Color_43': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 5462,
#    'Aclass': 'H',
#    'hit': '100',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/222.jpg',
#    'trial': 3,
#    'page_name': '222_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_44': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4913,
#    'Aclass': 'AI',
#    'hit': '1000',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/612.jpg',
#    'trial': 4,
#    'page_name': '612_b_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Azure'}},
#  'Trial_Color_45': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 5664,
#    'Aclass': 'AI',
#    'hit': '1001',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/876.jpg',
#    'trial': 5,
#    'page_name': '876_c_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Histogram'}},
#  'Trial_Color_46': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4582,
#    'Aclass': 'AI',
#    'hit': '1003',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/273.jpg',
#    'trial': 6,
#    'page_name': '273_b_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'Azure'}},
#  'Trial_Color_47': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 5342,
#    'Aclass': 'AI',
#    'hit': '1004',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/1026.jpg',
#    'trial': 7,
#    'page_name': '1026_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_48': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3885,
#    'Aclass': 'H',
#    'hit': '1006',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/672.jpg',
#    'trial': 8,
#    'page_name': '672_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_49': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 6190,
#    'Aclass': 'AI',
#    'hit': '1007',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/539.jpg',
#    'trial': 9,
#    'page_name': '539_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_50': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4574,
#    'Aclass': 'H',
#    'hit': '1008',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/543.jpg',
#    'trial': 10,
#    'page_name': '543_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_51': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4652,
#    'Aclass': 'AI',
#    'hit': '1010',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/345.jpg',
#    'trial': 11,
#    'page_name': '345_b_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Azure'}},
#  'Trial_Color_52': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3314,
#    'Aclass': 'AI',
#    'hit': '1011',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/305.jpg',
#    'trial': 12,
#    'page_name': '305_b_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'Azure'}},
#  'Trial_Color_53': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4958,
#    'Aclass': 'H',
#    'hit': '1012',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/973.jpg',
#    'trial': 13,
#    'page_name': '973_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_54': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3473,
#    'Aclass': 'AI',
#    'hit': '1014',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/653.jpg',
#    'trial': 14,
#    'page_name': '653_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_55': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 5902,
#    'Aclass': 'H',
#    'hit': '1015',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/522.jpg',
#    'trial': 15,
#    'page_name': '522_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_56': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4528,
#    'Aclass': 'AI',
#    'hit': '1017',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/1149.jpg',
#    'trial': 16,
#    'page_name': '1149_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_57': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4285,
#    'Aclass': 'H',
#    'hit': '1019',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/144.jpg',
#    'trial': 17,
#    'page_name': '144_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_58': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3798,
#    'Aclass': 'H',
#    'hit': '102',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/794.jpg',
#    'trial': 18,
#    'page_name': '794_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_59': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3274,
#    'Aclass': 'H',
#    'hit': '1020',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/83.jpg',
#    'trial': 19,
#    'page_name': '83_e_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'ChatGPT'}},
#  'Trial_Color_60': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 5858,
#    'Aclass': 'AI',
#    'hit': '1022',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/1113.jpg',
#    'trial': 20,
#    'page_name': '1113_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_61': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 6333,
#    'Aclass': 'AI',
#    'hit': '1024',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/264.jpg',
#    'trial': 21,
#    'page_name': '264_e_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'ChatGPT'}},
#  'Trial_Color_62': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4626,
#    'Aclass': 'H',
#    'hit': '1025',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/290.jpg',
#    'trial': 22,
#    'page_name': '290_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_63': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3588,
#    'Aclass': 'AI',
#    'hit': '1026',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/133.jpg',
#    'trial': 23,
#    'page_name': '133_c_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'Histogram'}},
#  'Trial_Color_64': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4661,
#    'Aclass': 'H',
#    'hit': '1027',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/204.jpg',
#    'trial': 24,
#    'page_name': '204_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_65': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3361,
#    'Aclass': 'H',
#    'hit': '1028',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/958.jpg',
#    'trial': 25,
#    'page_name': '958_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_66': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3378,
#    'Aclass': 'H',
#    'hit': '103',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/1130.jpg',
#    'trial': 26,
#    'page_name': '1130_e_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'ChatGPT'}},
#  'Trial_Color_67': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 6110,
#    'Aclass': 'H',
#    'hit': '1030',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/794.jpg',
#    'trial': 27,
#    'page_name': '794_d_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Google'}},
#  'Trial_Color_68': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4191,
#    'Aclass': 'H',
#    'hit': '1031',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/1042.jpg',
#    'trial': 28,
#    'page_name': '1042_d_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Google'}},
#  'Trial_Color_69': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4889,
#    'Aclass': 'AI',
#    'hit': '1032',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/563.jpg',
#    'trial': 29,
#    'page_name': '563_c_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'Histogram'}},
#  'Trial_Color_70': {'workerID': 'A3O81LHBBI8NPK',
#   'workerData': {'country': 'United States',
#    'age': '41-45',
#    'engagement': '8',
#    'difficulty': '2',
#    'mode': 'live',
#    'gender': 'female',
#    'education': 'high school',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3961,
#    'Aclass': 'AI',
#    'hit': '1034',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/108.jpg',
#    'trial': 30,
#    'page_name': '108_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'human',
# ...
#    'trial': 17,
#    'page_name': '1128_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_978': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 5976,
#    'Aclass': 'H',
#    'hit': '102',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/510.jpg',
#    'trial': 18,
#    'page_name': '510_e_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'ChatGPT'}},
#  'Trial_Color_979': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 5880,
#    'Aclass': 'H',
#    'hit': '1020',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/678.jpg',
#    'trial': 19,
#    'page_name': '678_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_980': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3839,
#    'Aclass': 'AI',
#    'hit': '1022',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/66.jpg',
#    'trial': 20,
#    'page_name': '66_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_981': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4224,
#    'Aclass': 'AI',
#    'hit': '1024',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/654.jpg',
#    'trial': 21,
#    'page_name': '654_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_982': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3912,
#    'Aclass': 'H',
#    'hit': '1025',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/1091.jpg',
#    'trial': 22,
#    'page_name': '1091_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_983': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4151,
#    'Aclass': 'AI',
#    'hit': '1026',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/663.jpg',
#    'trial': 23,
#    'page_name': '663_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_984': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4207,
#    'Aclass': 'H',
#    'hit': '1027',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/91.jpg',
#    'trial': 24,
#    'page_name': '91_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_985': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4520,
#    'Aclass': 'H',
#    'hit': '1028',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/735.jpg',
#    'trial': 25,
#    'page_name': '735_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_986': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 9127,
#    'Aclass': 'AI',
#    'hit': '103',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/835.jpg',
#    'trial': 26,
#    'page_name': '835_b_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'Azure'}},
#  'Trial_Color_987': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3224,
#    'Aclass': 'H',
#    'hit': '1030',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/24.jpg',
#    'trial': 27,
#    'page_name': '24_c_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'Histogram'}},
#  'Trial_Color_988': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3736,
#    'Aclass': 'AI',
#    'hit': '1031',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/711.jpg',
#    'trial': 28,
#    'page_name': '711_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  'Trial_Color_989': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4383,
#    'Aclass': 'H',
#    'hit': '1032',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/812.jpg',
#    'trial': 29,
#    'page_name': '812_e_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'ChatGPT'}},
#  'Trial_Color_990': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3504,
#    'Aclass': 'AI',
#    'hit': '1034',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/127.jpg',
#    'trial': 30,
#    'page_name': '127_d_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '2',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Google'}},
#  'Trial_Color_991': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3560,
#    'Aclass': 'AI',
#    'hit': '1036',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/1108.jpg',
#    'trial': 31,
#    'page_name': '1108_b_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'Azure'}},
#  'Trial_Color_992': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3264,
#    'Aclass': 'AI',
#    'hit': '1039',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/1060.jpg',
#    'trial': 32,
#    'page_name': '1060_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_993': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3735,
#    'Aclass': 'AI',
#    'hit': '1040',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/769.jpg',
#    'trial': 33,
#    'page_name': '769_c_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'Histogram'}},
#  'Trial_Color_994': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4208,
#    'Aclass': 'H',
#    'hit': '1042',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/654.jpg',
#    'trial': 34,
#    'page_name': '654_e_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'ChatGPT'}},
#  'Trial_Color_995': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4404,
#    'Aclass': 'AI',
#    'hit': '1043',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/96.jpg',
#    'trial': 35,
#    'page_name': '96_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'human',
#    'object_groundtruth': '0',
#    'machine_groundtruth': ''}},
#  'Trial_Color_996': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 4724,
#    'Aclass': 'AI',
#    'hit': '1044',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/704.jpg',
#    'trial': 36,
#    'page_name': '704_c_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'Histogram'}},
#  'Trial_Color_997': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 3704,
#    'Aclass': 'H',
#    'hit': '1045',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/337.jpg',
#    'trial': 37,
#    'page_name': '337_b_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'Azure'}},
#  'Trial_Color_998': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 9264,
#    'Aclass': 'AI',
#    'hit': '1047',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/720.jpg',
#    'trial': 38,
#    'page_name': '720_d_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '0',
#    'machine_groundtruth': 'Google'}},
#  'Trial_Color_999': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 2808,
#    'Aclass': 'AI',
#    'hit': '1048',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/187.jpg',
#    'trial': 39,
#    'page_name': '187_d_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'ai',
#    'response_object': '1',
#    'groundtruth': 'machine',
#    'object_groundtruth': '1',
#    'machine_groundtruth': 'Google'}},
#  'Trial_Color_1000': {'workerID': 'A31Z5TPD8QKE26',
#   'workerData': {'country': 'United States',
#    'age': '36-40',
#    'engagement': '9',
#    'difficulty': '10',
#    'mode': 'live',
#    'gender': 'male',
#    'education': 'bachelor',
#    'ai-experience': '1',
#    'condition': 0,
#    'native': 'yes'},
#   'trialData': {'rt': 6031,
#    'Aclass': 'H',
#    'hit': '1049',
#    'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/523.jpg',
#    'trial': 40,
#    'page_name': '523_a_0.html/',
#    'phase': 'TEST',
#    'response_gender': 'NA',
#    'response_speaker': 'h',
#    'response_object': '2',
#    'groundtruth': 'human',
#    'object_groundtruth': '1',
#    'machine_groundtruth': ''}},
#  ...}

# %%
len()
# Out:
# (1280,)

# %%
trial_data['trialData']
# Out:
# {'rt': 5129,
#  'Aclass': 'Machine',
#  'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/color_det/65.jpg',
#  'trial': 100,
#  'page_name': '65_d_0.html/',
#  'phase': 'TEST',
#  'response_gender': 'NA',
#  'response_speaker': 'machine',
#  'response_object': '1',
#  'groundtruth': 'machine',
#  'object_groundtruth': '0',
#  'machine_groundtruth': 'Google',
#  'imgtype': 'naturaldesign'}
