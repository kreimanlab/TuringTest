# %%
#complete_humanjudge.json
import json
import numpy as np

json_file_path = 'Data_all/complete_humanjudge.json'
plotname = 'complete_humanjudge'

with open(json_file_path, 'r') as j:
     contents = json.loads(j.read())
#print(contents)

#### process free viewing or visual search results seperately
json_file_write_FV = 'Data_all/complete_humanjudge_FV.json'
json_file_write_VS = 'Data_all/complete_humanjudge_VS.json'
FVonly = {}
VSonly = {}
for trialid in contents:
    if '_FV_' in trialid:
        FVonly[trialid] = contents[trialid]
    else:
        VSonly[trialid] = contents[trialid]

#print(VSonly)
with open(json_file_write_FV, "w") as fp:
    json.dump(FVonly,fp)
with open(json_file_write_VS, "w") as fp:
    json.dump(VSonly,fp)

###### check model list
modelist = []
for trialid in contents:
    trialinfor_modelname = contents[trialid]['trialData']['machine_groundtruth']
    if trialinfor_modelname not in modelist:
        if len(trialinfor_modelname)>1:
            modelist.append(trialinfor_modelname)

#find unique list of models
print(modelist)
print(len(contents)/12)

######################### AGE ##############
json_file_path = 'Data_all/demographic_age_bin1.json'

with open(json_file_path, 'r') as j:
     contents = json.loads(j.read())

modelist = []
for trialid in contents:
    #print(contents[trialid]['trialData'])
    trialinfor_modelname = contents[trialid]['trialData']['machine_groundtruth']
    if trialinfor_modelname not in modelist:
        if len(trialinfor_modelname)>1:
            modelist.append(trialinfor_modelname)

#find unique list of models
print(modelist)
print(len(contents)/12)

json_file_path = 'Data_all/demographic_age_bin2.json'

with open(json_file_path, 'r') as j:
     contents = json.loads(j.read())

modelist = []
for trialid in contents:
    #print(contents[trialid]['trialData'])
    trialinfor_modelname = contents[trialid]['trialData']['machine_groundtruth']
    if trialinfor_modelname not in modelist:
        if len(trialinfor_modelname)>1:
            modelist.append(trialinfor_modelname)

#find unique list of models
print(modelist)
print(len(contents)/12)

json_file_path = 'Data_all/demographic_age_bin3.json'

with open(json_file_path, 'r') as j:
     contents = json.loads(j.read())

modelist = []
for trialid in contents:
    #print(contents[trialid]['trialData'])
    trialinfor_modelname = contents[trialid]['trialData']['machine_groundtruth']
    if trialinfor_modelname not in modelist:
        if len(trialinfor_modelname)>1:
            modelist.append(trialinfor_modelname)

#find unique list of models
print(modelist)
print(len(contents)/12)
######################### GENDER ##############
json_file_path = 'Data_all/demographic_female.json'
plotname = 'barplot_female_combined'

with open(json_file_path, 'r') as j:
     contents = json.loads(j.read())

modelist = []
for trialid in contents:
    #print(contents[trialid]['trialData'])
    trialinfor_modelname = contents[trialid]['trialData']['machine_groundtruth']
    if trialinfor_modelname not in modelist:
        if len(trialinfor_modelname)>1:
            modelist.append(trialinfor_modelname)

#find unique list of models
print(modelist)
print(len(contents)/12)

json_file_path = 'Data_all/demographic_male.json'
plotname = 'barplot_female_combined'

with open(json_file_path, 'r') as j:
     contents = json.loads(j.read())

modelist = []
for trialid in contents:
    #print(contents[trialid]['trialData'])
    trialinfor_modelname = contents[trialid]['trialData']['machine_groundtruth']
    if trialinfor_modelname not in modelist:
        if len(trialinfor_modelname)>1:
            modelist.append(trialinfor_modelname)

#find unique list of models
print(modelist)
print(len(contents)/12)

######################### EDUCATION ##############
json_file_path = 'Data_all/demographic_edu_bin1.json'
plotname = 'barplot_edu_bin1'

with open(json_file_path, 'r') as j:
     contents = json.loads(j.read())

modelist = []
for trialid in contents:
    #print(contents[trialid]['trialData'])
    trialinfor_modelname = contents[trialid]['trialData']['machine_groundtruth']
    if trialinfor_modelname not in modelist:
        if len(trialinfor_modelname)>1:
            modelist.append(trialinfor_modelname)
print(modelist)
print(len(contents)/12)

            
json_file_path = 'Data_all/demographic_edu_bin2.json'
plotname = 'barplot_edu_bin1'

with open(json_file_path, 'r') as j:
     contents = json.loads(j.read())

modelist = []
for trialid in contents:
    #print(contents[trialid]['trialData'])
    trialinfor_modelname = contents[trialid]['trialData']['machine_groundtruth']
    if trialinfor_modelname not in modelist:
        if len(trialinfor_modelname)>1:
            modelist.append(trialinfor_modelname)

print(modelist)
print(len(contents)/12)


json_file_path = 'Data_all/demographic_edu_bin3.json'
plotname = 'barplot_edu_bin1'

with open(json_file_path, 'r') as j:
     contents = json.loads(j.read())

modelist = []
for trialid in contents:
    #print(contents[trialid]['trialData'])
    trialinfor_modelname = contents[trialid]['trialData']['machine_groundtruth']
    if trialinfor_modelname not in modelist:
        if len(trialinfor_modelname)>1:
            modelist.append(trialinfor_modelname)

print(modelist)
print(len(contents)/12)


######################### AI ##############
json_file_path = 'Data_all/SVM_AIJudge_FV_balanced.json'
plotname = 'FV_AI'

with open(json_file_path, 'r') as j:
     contents = json.loads(j.read())

modelist = []
for trialid in contents:
    #print(contents[trialid]['trialData'])
    trialinfor_modelname = contents[trialid]['trialData']['machine_groundtruth']
    if trialinfor_modelname not in modelist:
        if len(trialinfor_modelname)>1:
            modelist.append(trialinfor_modelname)

#find unique list of models
print(modelist)


json_file_path = 'Data_all/10_SVM_AIJudge_balanced.json'
plotname = 'VS_AI'

with open(json_file_path, 'r') as j:
     contents = json.loads(j.read())

modelist = []
for trialid in contents:
    #print(contents[trialid]['trialData'])
    trialinfor_modelname = contents[trialid]['trialData']['machine_groundtruth']
    if trialinfor_modelname not in modelist:
        if len(trialinfor_modelname)>1:
            modelist.append(trialinfor_modelname)

#find unique list of models
print(modelist)
# Out:
# ['GBVS', 'IVSN', 'DeepGazeIII']
# 192.0
# ['IVSN', 'GBVS', 'DeepGazeIII']
# 56.0
# ['GBVS', 'IVSN', 'DeepGazeIII']
# 76.0
# ['IVSN', 'DeepGazeIII', 'GBVS']
# 60.0
# ['GBVS', 'IVSN', 'DeepGazeIII']
# 85.0
# ['IVSN', 'DeepGazeIII', 'GBVS']
# 106.0
# ['GBVS', 'IVSN', 'DeepGazeIII']
# 73.0
# ['DeepGazeIII', 'IVSN', 'GBVS']
# 102.0
# ['IVSN', 'DeepGazeIII', 'GBVS']
# 16.0
# ['DeepGazeIII', 'GBVS', 'IVSN']
# ['DeepGazeIII', 'GBVS', 'IVSN']
