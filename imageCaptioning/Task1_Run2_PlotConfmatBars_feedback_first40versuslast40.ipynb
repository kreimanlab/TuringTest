# %%
import json
import matplotlib.pyplot as plt
import numpy as np
from colour import Color
import seaborn as sn
import pandas as pd
from matplotlib.patches import Rectangle
 
import pingouin as pg
from scipy import stats
import random
import math
import statsmodels.api as sm 
from statsmodels.formula.api import ols

def outputIconForStats(pval):
    if pval <= 0.05:
        icon = '*'
    else:
        icon = ' '
    return icon

def ConvertDictToDataFrame(datadict):
    #data = {'col_1': [3, 2, 1, 0], 'col_2': ['a', 'b', 'c', 'd']}    
    X = []
    Y = []
    for key in datadict.keys():
        for ele in datadict[key]:
            X.append(ele)
            Y.append(key)
        
    data = {'X': X, 'group': Y}
    df = pd.DataFrame.from_dict(data)
    return df

def ComputeStats_group1(d_cond):
    #compare against chance
    r_data = np.random.choice([0, 1], size=len(d_cond), p=[.5, .5])
    result = pg.ttest(d_cond, r_data, correction=True) 
    pval = result.at['T-test',"p-val"]
    Tval = result.at['T-test',"T"]
    dof = math.floor(result.at['T-test',"dof"])
    icon = outputIconForStats(pval)
    return icon, pval, Tval, dof

def ComputeStats_group2(data_d1, data_d2):
    result = pg.ttest(data_d1, data_d2, correction=True) 

    # reporting format in Turing project (p < 10−15, two-tailed t-test, t = 8.5, df = 478)
    pval = result.at['T-test',"p-val"]
    Tval = result.at['T-test',"T"]
    dof = math.floor(result.at['T-test',"dof"])
    icon = outputIconForStats(pval)
    return icon, pval, Tval, dof
    
def ComputeStats_group3(data_dict):
    df = ConvertDictToDataFrame(data_dict)
    #print(df)
    mod = ols('X ~ group', data=df).fit()
    aov_table = sm.stats.anova_lm(mod, typ=2)
    
    #A one-way ANOVA revealed that there [was or was not] a statistically significant difference in [dependent variable] 
    #between at least two groups (F(between groups df, within groups df) = [F-value], p = [p-value]).
    BetweenGP_df = aov_table.df.group
    WithinGP_df = aov_table.df.Residual
    Fval = aov_table.F.group
    pval = aov_table['PR(>F)'].group
    icon = outputIconForStats(pval)
    return icon, BetweenGP_df, WithinGP_df, Fval, pval

def displayStats_group12(pval, Tval, dof):    
    if pval < 0.05:
        print('There is difference between data1 and data2.')
        if pval > 0.01 and pval < 0.05:
            print("(p < 0.05, two-tailed t-test, t = " + str("{0:.2f}".format(Tval)) + ", df = " + str(dof) + ")")
        elif pval > 0.001 and pval <= 0.01:
            print("(p < 0.01, two-tailed t-test, t = " + str("{0:.2f}".format(Tval)) + ", df = " + str(dof) + ")")
        elif pval > 0.0001 and pval <= 0.001:
            print("(p < 0.001, two-tailed t-test, t = " + str("{0:.2f}".format(Tval)) + ", df = " + str(dof) + ")")
        else:
            print("(p < 0.0001, two-tailed t-test, t = " + str("{0:.2f}".format(Tval)) + ", df = " + str(dof) + ")")
    else:
        print('There is NO difference between data1 and data2.')
        print("(p > 0.05, two-tailed t-test, t = " + str("{0:.2f}".format(Tval)) + ", df = " + str(dof) + ")")

        
def displayStats_group3(BetweenGP_df, WithinGP_df, Fval, pval):    
    print("F(" + str(BetweenGP_df) + ", " + str(WithinGP_df) + ") = " + str(Fval) +", p-val=" + str(pval))

    
def boostrap(data1, data2):
    import random
    import math
    store = []
    sample_mean = []
    if len(data1) < len(data2):
        SampleTimes = math.ceil(len(data1)/2)
        BootstrapTimes = len(data1)
    else:
        SampleTimes = math.ceil(len(data2)/2)
        BootstrapTimes = len(data2)
        
    print("bootstraptime",BootstrapTimes,"sampletime",SampleTimes)
    for i in range(BootstrapTimes):
        y1 = random.sample(data1, SampleTimes)
        #print(y1)
        y2 = random.sample(data2, SampleTimes)
        #print(y2)
        y_comb = y1+y2
        #print(y_comb)
        sample_mean.append(np.mean(np.array(y_comb), axis=0))
    
    stdval = np.std(np.array(sample_mean), axis=0)
    return stdval

def ConcatData(data1, data2):
    import random
    import math
    
    #print(data1)
    #print(data2)
    if len(data1) < len(data2):        
        BootstrapTimes = len(data1)
    else:        
        BootstrapTimes = len(data2)
    
    #print(BootstrapTimes)
    y1 = random.sample(data1, BootstrapTimes)
    #print(y1)
    y2 = random.sample(data2, BootstrapTimes)
    #print(y2)
    y_comb = y1+y2
    y_comb = np.array(y_comb)        
    return y_comb


def ComputeBarStdConfMat(contents):
    modelist = ['git', 'ofa', 'blip', 'clipcap', 'microsoft_api']
    print(modelist)
    
    #initialize matrix of absolute counts   
    result = {'human':0, 'countH':0, 'machine':0, 'countM': 0, 'result_H':[], 'result_M':[]}
    for modelname in modelist:
        result[modelname] = 0
        result['count_'+modelname] = 0
        result['result_'+modelname]=[]
    #print(result)

    # Iterating over keys
    for trialid in contents:
        trialinfor = contents[trialid]['trialData']
        if trialinfor['machine_groundtruth'] == "catch":
            continue
        if trialinfor['groundtruth'] == 'human':
            result['countH'] = result['countH'] + 1
            if trialinfor['response_speaker'] == trialinfor['groundtruth']:
                result['human'] = result['human'] + 1
                result['result_H'].append(1)
            else:
                result['result_H'].append(0)
                
        else:
            result['countM'] = result['countM'] + 1
            if trialinfor['response_speaker'] == trialinfor['groundtruth']:
                result['machine'] = result['machine'] + 1
                result['result_M'].append(1)
            else:
                result['result_M'].append(0)
                
            modelname = trialinfor['machine_groundtruth']
            
            result['count_'+modelname] = result['count_'+modelname] + 1
            if trialinfor['response_speaker'] == trialinfor['groundtruth']:
                result[modelname] = result[modelname] + 1
                result['result_' + modelname].append(1)
            else:
                result['result_' + modelname].append(0)
                
    #print(result)

    #compute confusion matrix
    result_conf_mat = np.zeros((2+len(modelist),2),'float32')
    result_conf_mat[0][0] = result['human']/result['countH']
    result_conf_mat[0][1] = (result['countH'] - result['human'])/result['countH']  
    result_conf_mat[1][0] = (result['countM'] - result['machine'])/result['countM']
    result_conf_mat[1][1] = result['machine']/result['countM']

    for i, modelname in enumerate(modelist):
        result_conf_mat[i+2][0] = (result['count_'+modelname] - result[modelname])/result['count_'+modelname]
        result_conf_mat[i+2][1] = result[modelname]/result['count_'+modelname]

    result_conf_mat = np.around(result_conf_mat, decimals=2)
        
    stdmodelist = ['M', 'git', 'ofa', 'blip', 'clipcap', 'microsoft_api']
    modelist_stats = ['Machine', 'GIT', 'OFA', 'BLIP', 'ClipCap', 'Microsoft_API']
    top1 = []
    top1_std = []
    resultFlist = {}
    data1tot = result['result_H']
    for i in range(1+len(modelist)):
        #print(i)
        top1.append((result_conf_mat[0][0]+result_conf_mat[i+1][1])/2)
        # compute bootstrap accuracy
        # compute and save std for top1 accuracy
        top_std_AI = boostrap(result['result_H'], result['result_' + stdmodelist[i]])
        top1_std.append(top_std_AI)
        data2tot = result['result_' + stdmodelist[i]]
        #resultFlist[modelist_stats[i]] = np.concatenate((data1tot,data2tot))
        resultFlist[modelist_stats[i]] = ConcatData(data1tot,data2tot)
    #print(top1)
    
    return top1, top1_std, result_conf_mat, resultFlist


### plots for grouping demographic information
def plot_res_demographics(condition_chosen_list, TextFilePath, plotname,facebarcolor, condition_results):
    
    compiledAllConds = {}
    
    modelist = ['Machine', 'GIT', 'OFA', 'BLIP', 'ClipCap', 'Microsoft_API']
    Pdata = {} #data stored for computing statistics 
    #initialize PData
    for i in range(0,len(modelist)):
        Pdata[modelist[i]] = {}
    
    for condition_chosen in condition_chosen_list:
        
        top1, top1std, result_conf_mat, resultFlist = ComputeBarStdConfMat(condition_results[condition_chosen])
        
        for i in range(0,len(modelist)):
            Pdata[modelist[i]][condition_chosen] = resultFlist[modelist[i]]
        
#         #compute barplot and errorbar of barplot
#         top1 = []
#         top1std = []

#         #compute confusion matrix
#         result_conf_mat = 

        compiledAllConds[condition_chosen] = top1
        compiledAllConds[condition_chosen +'_std'] = top1std
    
    ### we have the compiled resutls now; lets calculate stats
    chancePval = []
    groupPval = []
    
    for i in range(0,len(modelist)):
        for condition_chosen in condition_chosen_list:        
            #compute against chance 50%
            d_cond = Pdata[modelist[i]][condition_chosen]
            icon, pval, Tval, dof = ComputeStats_group1(d_cond)
            chancePval.append(icon)
        if len(Pdata[modelist[i]].keys()) == 2:
            data_d1 = Pdata[modelist[i]][condition_chosen_list[0]]
            data_d2 = Pdata[modelist[i]][condition_chosen_list[1]]
            icon, pval, Tval, dof =  ComputeStats_group2(data_d1, data_d2)
            groupPval.append(icon)
        elif len(Pdata[modelist[i]].keys()) >= 3: 
            icon, BetweenGP_df, WithinGP_df, Fval, pval = ComputeStats_group3(Pdata[modelist[i]])
            groupPval.append(icon)
        else:
            print(Pdata[modelist[i]].keys())
            print("Oops!  This should NOT happen...")
        
    
    #data
    #x-axis
    years = list(range(1, len(modelist)))
    strtask = modelist
    #print(years)
    #print(strtask)

    # Figure Size
    fig, ax = plt.subplots(layout='constrained')
    x = np.arange(len(strtask))  # the label locations
    point_x = [] #for plotting stats * or n.s.
    
    width = 0.2  # the width of the bars
    if len(condition_chosen_list) == 2:
        multiplier = -0.5 #len(condition_chosen_list)
    else:
        multiplier = -1 #len(condition_chosen_list)
    #ngroups = len(condition_chosen_list)

    ax.add_patch(Rectangle((-0.5, 0.45), len(modelist), 0.1,facecolor='yellow'))
    #bar chart properties
    #ax.bar(strtask, top1, color ='black', width = 0.3)    

    for ind, condition_chosen in enumerate(condition_chosen_list):
    #for condition_chosen in condition_chosen_list:
    #for attribute, measurement in compiledAllConds.items():
        measurement = compiledAllConds[condition_chosen]
        measurement_std = compiledAllConds[condition_chosen + '_std']
        attribute = condition_chosen
        
        offset = width * multiplier

        rects = ax.bar(x + offset, measurement, yerr= measurement_std, width = width,alpha=0.5,
                       label=attribute, edgecolor='black', color=facebarcolor[ind], ecolor='black')#,
                       #align='center', alpha=0.5, ecolor='black', capsize=10,color ='black')
        #ax.bar_label(rects, padding=3)
        point_x.extend( (x+offset).tolist() )
        multiplier += 1
    
#     ax.bar(strtask, top1, yerr=top1std,
#        align='center', alpha=0.5, ecolor='black', capsize=10,
#        color ='black', width = 0.3)

    ########## ready for plotting stats
    #print(point_x)
    ###### getting statistics
    #chancePval, groupPval = getStats(condition_chosen_list, TextFilePath)
    point_x.sort(reverse=False)
    #print(point_x)
    for i, p in enumerate(point_x):        
        ax.text(p, .7, chancePval[i], fontsize=8, transform=ax.get_xaxis_transform())
    
    ax.set_xticks(x, strtask)
    ax.legend(loc='upper left', ncol=len(condition_chosen_list))

    ###### plot stats for each group of bars
    totalPx = len(point_x)
#     print(totalPx)
#     print(point_x)
    count = 0
    print(groupPval)
    for s1 in range(0,totalPx, len(condition_chosen_list)):
        center_x = 0
        for s2 in range(0,len(condition_chosen_list)):
            center_x = center_x + point_x[s1+s2]
        center_x = center_x/len(condition_chosen_list)
        starting_x = point_x[s1]
        ending_x = point_x[s1+len(condition_chosen_list)-1]
        plt.plot(   np.array([starting_x, ending_x]),
                           np.arange(2)*0+0.82, 'k', label='chance (50%)')
        ax.text(center_x, .8, groupPval[count], fontsize=8, transform=ax.get_xaxis_transform())
        count = count + 1
    
    ###### ending: plot stats for each group of bars
    
    plt.ylabel('Top-1 Accuracy')
    plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees

    plt.ylim(0.25, 1)
    #plt.xlim(0.5, len(years)+0.5)

    #draw chance 0.5 
    chancex =np.arange(len(years)+2)-0.5
    plt.plot(chancex, np.arange(len(chancex))*0+0.5, 'k--', label='chance (50%)')
    #plt.legend()

    fig.tight_layout()

    fig.set_figwidth(7)
    fig.set_figheight(5)

    #fig.legend(loc='upper center', bbox_to_anchor=(0.55, 1.0), ncol=3, fancybox=True, shadow=True,frameon=False)

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    plt.savefig(plotname + '.eps', format='eps', bbox_inches='tight')
    plt.savefig(plotname + '.png',  bbox_inches='tight')
    plt.show()
#     fig.savefig('../' + plotname + '.png', bbox_inches='tight')
#     fig.savefig('Human_judge_bars_Giorgia'+condition_chosen+'.pdf', bbox_inches='tight')
    
#     fig.savefig('Human_judge_bars_Giorgia'+condition_chosen+'.png', bbox_inches='tight')


# #======================With or without gender questions=======
# with open("./savedResults/compiled.json", 'r') as f:
#     CompiledResults = json.load(f)

# key = 'inlab' #choose from these choices: inlab, mturk
# folderpath = './plots/Task1_' + key + '_' #for saving the plots

# condition_chosen_list = ['inlab_gender','inlab_nogender']
# TextFilePath = './savedResults/Task1_' + key + '_' #not being used
# plotpathname = './plots/Task1_' + key + '_demor_WwoGenderQuesBarPlotOverall' #for saving the plots
# facebarcolor = ['dimgray','darkgrey','lightgrey']

# plot_res_demographics(condition_chosen_list, TextFilePath, plotpathname,facebarcolor, CompiledResults)

#====================== quality controls (mturk versus inlab) =======
calculation_type = 'first40vslast40' # exclude training samples when gather human results 
keep_catch_trials = False 

with open("./savedResults/compiled_feedback_{}.json".format(calculation_type), 'r') as f:
    CompiledResults = json.load(f)

key = 'mturk-feedback-last40' #choose from these choices: inlab, mturk
folderpath = './plots/Task1_' + key + '_' #for saving the plots

condition_chosen_list = ['mturk-feedback-first40','mturk-feedback-last40']
TextFilePath = './savedResults/Task1_' + key + '_' #not being used
plotpathname = './plots/Task1_' + key + '_demor_mturk_feedback_BarPlotOverall' #for saving the plots
facebarcolor = ['dimgray','darkgrey','lightgrey']

plot_res_demographics(condition_chosen_list, TextFilePath, plotpathname,facebarcolor, CompiledResults)
# Out:
# ['git', 'ofa', 'blip', 'clipcap', 'microsoft_api']
# bootstraptime 1010 sampletime 505
# bootstraptime 197 sampletime 99
# bootstraptime 193 sampletime 97
# bootstraptime 219 sampletime 110
# bootstraptime 211 sampletime 106
# bootstraptime 190 sampletime 95
# ['git', 'ofa', 'blip', 'clipcap', 'microsoft_api']
# bootstraptime 1010 sampletime 505
# /tmp/ipykernel_2820413/317912318.py:352: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   fig.tight_layout()
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# bootstraptime 211 sampletime 106
# bootstraptime 215 sampletime 108
# bootstraptime 189 sampletime 95
# bootstraptime 197 sampletime 99
# bootstraptime 218 sampletime 109
# [' ', ' ', '*', ' ', ' ', ' ']

# %%
def plot_res_demographics_singleplot(condition_chosen, TextFilePath, condition_results, folderpath, saveflag):
    
    top1, top1std, result_conf_mat, dummy = ComputeBarStdConfMat(condition_results[condition_chosen])
    
    modelist = ['Human', 'Machine', 'GIT', 'OFA', 'BLIP', 'ClipCap', 'Microsoft_API']
    df_cm = pd.DataFrame(result_conf_mat, index = [i for i in modelist],
                  columns = [i for i in ['Human','Machine']])
    plt.figure(figsize = (1.2,4.5))
    
    if condition_chosen == 'machine':
        sn.heatmap(df_cm, annot=True,robust=True, cmap='RdBu_r', vmin=0, vmax=1, cbar=False)
    else:
        sn.heatmap(df_cm, annot=True,robust=True, cmap='RdBu_r', vmin=0, vmax=1)

    plt.xlabel("Predicted")
    plt.ylabel("Ground Truth")
    
    plotname = condition_chosen
    plt.savefig(folderpath + plotname + '_overall_confmat.eps', format='eps', bbox_inches='tight')
    plt.savefig(folderpath + plotname + '_overall_confmat.png', bbox_inches='tight')
    plt.show()
    
    if saveflag == 1:
        np.save(TextFilePath + "confmat.np", result_conf_mat)
        
    #data
    #x-axis
    years = list(range(1, len(modelist)-1))
    strtask = modelist[1:]
    #print(years)
    #print(strtask)

    # Figure Size
    fig, ax = plt.subplots()

    ax.add_patch(Rectangle((-0.5, 0.45), len(modelist)-1, 0.1,facecolor='yellow'))
    #bar chart properties
    #ax.bar(strtask, top1, color ='black', width = 0.3)
    ax.bar(strtask, top1, yerr=top1std,
       align='center', alpha=0.5, ecolor='black', capsize=10,
       color ='black', width = 0.3)

    print('mean')
    print(top1)
    print('std')
    print(top1std)
    
    plt.ylabel('Top-1 Accuracy')
    plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees

    plt.ylim(0.3, 1)
    #plt.xlim(0.5, len(years)+0.5)

    #draw chance 0.5 
    chancex =np.arange(len(years)+1)
    plt.plot(chancex, np.arange(len(chancex))*0+0.5, 'k--', label='chance (50%)')
    #plt.legend()

    fig.tight_layout()

    fig.set_figwidth(3.5)
    fig.set_figheight(5)

    #fig.legend(loc='upper center', bbox_to_anchor=(0.55, 1.0), ncol=3, fancybox=True, shadow=True,frameon=False)

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    plt.savefig(folderpath + plotname + '_overall_barplot.eps', format='eps', bbox_inches='tight')
    plt.savefig(folderpath + plotname + '_overall_barplot.png', bbox_inches='tight')
    plt.show()



#======================Plot overall results (human judges)=======
calculation_type = 'first40vslast40' # exclude training samples when gather human results 
keep_catch_trials = False 
with open("./savedResults/compiled_feedback_{}.json".format(calculation_type), 'r') as f:
    CompiledResults = json.load(f)

#======================Plot overall results (human judges with feedback)=======   
key = 'mturk-feedback-first40' #choose from these choices: inlab, mturk-feedback
TextFilePath = './savedResults/Task1_' + key + '_' #not being used
folderpath = './plots/Task1_' + key + '_' #for saving the plots
saveflag = 0 #save confmat for final plots
plot_res_demographics_singleplot(key, TextFilePath, CompiledResults, folderpath, saveflag)

#======================Plot overall results (human judges without feedback)======= 
key = 'mturk-feedback-last40' #choose from these choices: inlab, mturk
TextFilePath = './savedResults/Task1_' + key + '_' #not being used
folderpath = './plots/Task1_' + key + '_' #for saving the plots
saveflag = 0 #save confmat for final plots
plot_res_demographics_singleplot(key, TextFilePath, CompiledResults, folderpath, saveflag)

# #======================Plot overall results (AI judges)=======
# with open("./savedResults/compiled_feedback_{}.json".format(calculation_type), 'r') as f:
#     CompiledResults = json.load(f)

# key = 'machine' #choose from these choices: inlab, mturk
# TextFilePath = './savedResults/Task1_' + key + '_' #not being used
# folderpath = './plots/Task1_' + key + '_' #for saving the plots
# saveflag = 0
# plot_res_demographics_singleplot(key, TextFilePath, CompiledResults, folderpath, saveflag)
# Out:
# ['git', 'ofa', 'blip', 'clipcap', 'microsoft_api']
# bootstraptime 1010 sampletime 505
# bootstraptime 197 sampletime 99
# bootstraptime 193 sampletime 97
# bootstraptime 219 sampletime 110
# bootstraptime 211 sampletime 106
# bootstraptime 190 sampletime 95
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# mean
# [0.6000000238418579, 0.6050000190734863, 0.5849999785423279, 0.5950000286102295, 0.6399999856948853, 0.5849999785423279]
# std
# [0.01067379974967633, 0.02714539609845078, 0.027852973588201435, 0.029016382294886737, 0.02654495537595864, 0.02984870909661309]
# ['git', 'ofa', 'blip', 'clipcap', 'microsoft_api']
# bootstraptime 1010 sampletime 505
# bootstraptime 211 sampletime 106
# bootstraptime 215 sampletime 108
# bootstraptime 189 sampletime 95
# bootstraptime 197 sampletime 99
# bootstraptime 218 sampletime 109
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# mean
# [0.5950000286102295, 0.5699999928474426, 0.5300000309944153, 0.6000000238418579, 0.6449999809265137, 0.6200000047683716]
# std
# [0.009924196695274407, 0.027892915470638293, 0.027032274489380007, 0.02884734884710944, 0.028979860247539128, 0.02688133390901006]

# %%
CompiledResults
# Out:
# {'inlab': [],
#  'inlab_gender': [],
#  'inlab_nogender': [],
#  'mturk': {'Trial_1': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 8743,
#     'human_groundtruth': 'Participant_21',
#     'hit': True,
#     'trial': 1,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0299.jpg',
#     'caption': 'a person holding open a magazine and reading it',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_2': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 5054,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 2,
#     'machine_groundtruth': 'git',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0045.jpg',
#     'caption': 'a group of people standing on top of a body of water',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_3': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1186,
#     'human_groundtruth': 'Participant_41',
#     'hit': True,
#     'trial': 3,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0050.jpg',
#     'caption': 'a zebra eats grass next to a fence',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_4': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1168,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 4,
#     'machine_groundtruth': 'microsoft_api',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0193.jpg',
#     'caption': 'elephants near a river',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_5': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1021,
#     'human_groundtruth': 'Participant_195',
#     'hit': True,
#     'trial': 5,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0174.jpg',
#     'caption': 'a man throwing a suitcase in the air',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_6': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1085,
#     'human_groundtruth': 'Participant_16',
#     'hit': True,
#     'trial': 6,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0330.jpg',
#     'caption': 'a cat is standing in front of a tree',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_7': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1283,
#     'human_groundtruth': 'Participant_100',
#     'hit': True,
#     'trial': 7,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0167.jpg',
#     'caption': 'a pair of scissors on a measuring board with string and a piece of purple fabric',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_8': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1233,
#     'human_groundtruth': 'Participant_146',
#     'hit': True,
#     'trial': 8,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0318.jpg',
#     'caption': 'a man and woman dancing together',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_9': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1299,
#     'human_groundtruth': 'Participant_99',
#     'hit': True,
#     'trial': 9,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0395.jpg',
#     'caption': 'a man has his hands up in victory next to his motorcycle',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_10': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1515,
#     'human_groundtruth': 'Participant_187',
#     'hit': True,
#     'trial': 10,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0100.jpg',
#     'caption': 'a middle-aged man smiling while opening a refrigerator',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_11': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1100,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 11,
#     'machine_groundtruth': 'clipcap',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0246.jpg',
#     'caption': 'a snowboarder is doing a trick on a snowboard',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_12': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1250,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 12,
#     'machine_groundtruth': 'blip',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0385.jpg',
#     'caption': 'a little boy standing in front of a mirror holding a teddy bear',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_13': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1148,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 13,
#     'machine_groundtruth': 'clipcap',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0132.jpg',
#     'caption': 'a table topped with cookies and doughnuts',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_14': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 949,
#     'human_groundtruth': 'Participant_12',
#     'hit': True,
#     'trial': 14,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0051.jpg',
#     'caption': 'a white female sitting at a table with different cups in the background talking on her cell phone ',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_15': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1069,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 15,
#     'machine_groundtruth': 'microsoft_api',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0085.jpg',
#     'caption': 'a group of people sitting on a bench',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_16': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1201,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 16,
#     'machine_groundtruth': 'git',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0319.jpg',
#     'caption': 'a large white boat on the water near the shore',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_17': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1059,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 17,
#     'machine_groundtruth': 'microsoft_api',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0029.jpg',
#     'caption': 'a bus on the street',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_18': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1012,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 18,
#     'machine_groundtruth': 'microsoft_api',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0316.jpg',
#     'caption': 'a bicycle with a red frame',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_19': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1117,
#     'human_groundtruth': 'Participant_112',
#     'hit': True,
#     'trial': 19,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0314.jpg',
#     'caption': 'a man laying next to a skateboard on the grass',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_20': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1100,
#     'human_groundtruth': 'Participant_221',
#     'hit': True,
#     'trial': 20,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0206.jpg',
#     'caption': 'a restaurant can be seen from the window of a bus',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_21': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1167,
#     'human_groundtruth': 'Participant_49',
#     'hit': True,
#     'trial': 21,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0389.jpg',
#     'caption': 'business meeting among well dressed professional individuals',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_22': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1445,
#     'human_groundtruth': 'Participant_199',
#     'hit': True,
#     'trial': 22,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0399.jpg',
#     'caption': 'a woman is singing with a man on stage',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_23': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1068,
#     'human_groundtruth': 'Participant_114',
#     'hit': True,
#     'trial': 23,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0194.jpg',
#     'caption': 'a woman wearing socks is laying on the bed with a cat and a laptop',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_24': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1237,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 24,
#     'machine_groundtruth': 'blip',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0146.jpg',
#     'caption': 'a bowl of oranges, pears, and walnuts on a table',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_25': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1119,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 25,
#     'machine_groundtruth': 'blip',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0252.jpg',
#     'caption': 'a mannequin torso with an orange bag on it',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_26': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1028,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 26,
#     'machine_groundtruth': 'blip',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0172.jpg',
#     'caption': 'a group of people standing around a bar',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_27': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1754,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 27,
#     'machine_groundtruth': 'microsoft_api',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0270.jpg',
#     'caption': 'a man holding a tennis racket',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_28': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1071,
#     'human_groundtruth': 'Participant_224',
#     'hit': True,
#     'trial': 28,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0168.jpg',
#     'caption': 'a bottle of chryseia wine and a quarter full wineglass',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_29': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1052,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 29,
#     'machine_groundtruth': 'ofa',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0041.jpg',
#     'caption': 'a stop sign and a one way sign on the street',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_30': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 979,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 30,
#     'machine_groundtruth': 'microsoft_api',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0164.jpg',
#     'caption': 'a basket of apples',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_31': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1062,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 31,
#     'machine_groundtruth': 'blip',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0250.jpg',
#     'caption': 'a kitchen with a refrigerator and a sink',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_32': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1233,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 32,
#     'machine_groundtruth': 'clipcap',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0167.jpg',
#     'caption': 'a pair of scissors sitting on top of a table',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_33': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 974,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 33,
#     'machine_groundtruth': 'ofa',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0029.jpg',
#     'caption': 'a bus is parked on the side of a city street',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_34': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1069,
#     'human_groundtruth': 'Participant_103',
#     'hit': True,
#     'trial': 34,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0069.jpg',
#     'caption': 'a hotel room bed and an open mirrored closet',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_35': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1028,
#     'human_groundtruth': 'Participant_227',
#     'hit': True,
#     'trial': 35,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0021.jpg',
#     'caption': 'a bathroom with uneven geometric tiles',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_36': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1149,
#     'human_groundtruth': 'Participant_49',
#     'hit': True,
#     'trial': 36,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0034.jpg',
#     'caption': 'zoo that has multiple animals including zebras and giraffes',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_37': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1028,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 37,
#     'machine_groundtruth': 'git',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0115.jpg',
#     'caption': 'a white bus driving down a city street',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_38': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 963,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 38,
#     'machine_groundtruth': 'microsoft_api',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0014.jpg',
#     'caption': 'a plate of broccoli',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_39': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1062,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 39,
#     'machine_groundtruth': 'clipcap',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0159.jpg',
#     'caption': 'a group of people skiing down a snow covered slope',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_40': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1082,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 40,
#     'machine_groundtruth': 'blip',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0125.jpg',
#     'caption': 'a couple of giraffe standing next to a white car',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_41': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 2950,
#     'human_groundtruth': 'Participant_111',
#     'hit': True,
#     'trial': 41,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0220.jpg',
#     'caption': 'a person in a back coat walking down a sidewalk talking on a cellphone',
#     'response_speaker': 'machine',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_42': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 2116,
#     'human_groundtruth': 'Participant_69',
#     'hit': True,
#     'trial': 42,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0086.jpg',
#     'caption': 'a man on a surfboard riding a wave ',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_43': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1903,
#     'human_groundtruth': 'Participant_84',
#     'hit': True,
#     'trial': 43,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0253.jpg',
#     'caption': 'a white cat with its tongue licking its nose sits near a window',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_44': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 2351,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 44,
#     'machine_groundtruth': 'catch',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0090.jpg',
#     'caption': 'woman woman woman woman woman woman',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_45': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1914,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 45,
#     'machine_groundtruth': 'catch',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0202.jpg',
#     'caption': 'beach beach beach beach beach beach beach beach',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_46': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1548,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 46,
#     'machine_groundtruth': 'ofa',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0188.jpg',
#     'caption': 'a bathroom with a sink and a toilet',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_47': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1334,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 47,
#     'machine_groundtruth': 'ofa',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0209.jpg',
#     'caption': 'a bathroom with a toilet and a roll of toilet paper',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_48': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1266,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 48,
#     'machine_groundtruth': 'clipcap',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0280.jpg',
#     'caption': 'a man in a red shirt performing a trick on a red board',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_49': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1650,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 49,
#     'machine_groundtruth': 'ofa',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0032.jpg',
#     'caption': 'a woman is holding a vase with flowers in it',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_50': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1202,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 50,
#     'machine_groundtruth': 'catch',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0141.jpg',
#     'caption': 'repaired repaired repaired repaired repaired repaired repaired',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_51': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1448,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 51,
#     'machine_groundtruth': 'clipcap',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0187.jpg',
#     'caption': 'an elephant with tusks standing in a grassy area',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_52': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1273,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 52,
#     'machine_groundtruth': 'ofa',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0046.jpg',
#     'caption': 'a speed limit sign on the side of a road',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_53': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1277,
#     'human_groundtruth': 'Participant_127',
#     'hit': True,
#     'trial': 53,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0331.jpg',
#     'caption': 'two hockey players in the middle of a game with goalie in background',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_54': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1954,
#     'human_groundtruth': 'Participant_27',
#     'hit': True,
#     'trial': 54,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0070.jpg',
#     'caption': 'a group of people on skis standing in the snow',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_55': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1865,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 55,
#     'machine_groundtruth': 'catch',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0138.jpg',
#     'caption': 'bathroom bathroom bathroom bathroom bathroom bathroom',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_56': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1582,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 56,
#     'machine_groundtruth': 'blip',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0379.jpg',
#     'caption': 'a man in a suit and tie sitting at a table',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_57': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1765,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 57,
#     'machine_groundtruth': 'catch',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0242.jpg',
#     'caption': 'horse horse horse horse horse horse horse horse horse',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_58': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1534,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 58,
#     'machine_groundtruth': 'catch',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0011.jpg',
#     'caption': 'field field field field field field field field',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_59': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1204,
#     'human_groundtruth': 'Participant_72',
#     'hit': True,
#     'trial': 59,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0044.jpg',
#     'caption': 'a group of skiers on a mountain',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_60': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1546,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 60,
#     'machine_groundtruth': 'catch',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0153.jpg',
#     'caption': 'eating eating eating eating eating eating',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_61': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 2185,
#     'human_groundtruth': 'Participant_55',
#     'hit': True,
#     'trial': 61,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0054.jpg',
#     'caption': 'two men on a snowy ranch or farm with a horse and a cow',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_62': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1219,
#     'human_groundtruth': 'Participant_59',
#     'hit': True,
#     'trial': 62,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0121.jpg',
#     'caption': 'a man throws a frisbee by the beach',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_63': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 2853,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 63,
#     'machine_groundtruth': 'catch',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0324.jpg',
#     'caption': 'smiling smiling smiling smiling smiling smiling smiling smiling',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_64': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1629,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 64,
#     'machine_groundtruth': 'git',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0218.jpg',
#     'caption': 'a dog standing on top of a sandy beach',
#     'response_speaker': 'machine',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_65': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 2297,
#     'human_groundtruth': 'Participant_206',
#     'hit': True,
#     'trial': 65,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0392.jpg',
#     'caption': 'a group of people with blue t-shirts and name tags sit around a table smiling and posing',
#     'response_speaker': 'human',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_66': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1501,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 66,
#     'machine_groundtruth': 'catch',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0107.jpg',
#     'caption': 'sticks sticks sticks sticks sticks sticks sticks sticks sticks',
#     'response_speaker': 'machine',
#     'counterbalance': 14,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_67': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
#     'imagetype': 'COCO'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 1700,
#     'human_groundtruth': 'Participant_126',
#     'hit': True,
#     'trial': 67,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0103.jpg',
#     'caption': 'a parking meter in front of a brick building covered in ivy',
#     'response_speaker': 'machine',
#     'counterbalance': 14,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_68': {'workerID': 'AZED64FULUY92',
#    'workerData': {'country': 'Åland Islands',
#     'age': '18-20',
#     'engagement': '5',
#     'difficulty': '5',
#     'gender': 'female',
#     'education': 'high school',
#     'ai-experience': '1',
#     'native': 'yes',
# ...
#     'machine_groundtruth': 'catch',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0103.jpg',
#     'caption': 'in in in in in in in',
#     'response_speaker': 'machine',
#     'counterbalance': 7,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_979': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 6222,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 79,
#     'machine_groundtruth': 'microsoft_api',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0137.jpg',
#     'caption': 'a train on the railway tracks',
#     'response_speaker': 'machine',
#     'counterbalance': 7,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_980': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 3483,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 80,
#     'machine_groundtruth': 'microsoft_api',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0273.jpg',
#     'caption': 'a person with a purple flower',
#     'response_speaker': 'machine',
#     'counterbalance': 7,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_981': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 2794,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 81,
#     'machine_groundtruth': 'catch',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0346.jpg',
#     'caption': 'clouds clouds clouds clouds clouds clouds',
#     'response_speaker': 'machine',
#     'counterbalance': 7,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_982': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 3579,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 82,
#     'machine_groundtruth': 'clipcap',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0216.jpg',
#     'caption': 'a train that is sitting on the tracks',
#     'response_speaker': 'machine',
#     'counterbalance': 7,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_983': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 2939,
#     'human_groundtruth': 'Participant_156',
#     'hit': True,
#     'trial': 83,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0182.jpg',
#     'caption': 'a guy on a bicycle looking into the water',
#     'response_speaker': 'human',
#     'counterbalance': 7,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_984': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 2706,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 84,
#     'machine_groundtruth': 'catch',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0334.jpg',
#     'caption': 'motorcycle motorcycle motorcycle motorcycle motorcycle motorcycle motorcycle motorcycle',
#     'response_speaker': 'machine',
#     'counterbalance': 7,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_985': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 3500,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 85,
#     'machine_groundtruth': 'clipcap',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0180.jpg',
#     'caption': 'a white toilet sitting in a bathroom next to a window',
#     'response_speaker': 'machine',
#     'counterbalance': 7,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_986': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 2378,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 86,
#     'machine_groundtruth': 'catch',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0010.jpg',
#     'caption': 'cluttered cluttered cluttered cluttered cluttered cluttered cluttered',
#     'response_speaker': 'machine',
#     'counterbalance': 7,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_987': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 2725,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 87,
#     'machine_groundtruth': 'catch',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0377.jpg',
#     'caption': 'woman woman woman woman woman woman woman woman',
#     'response_speaker': 'machine',
#     'counterbalance': 7,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_988': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 2731,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 88,
#     'machine_groundtruth': 'catch',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0261.jpg',
#     'caption': 'front front front front front front front front',
#     'response_speaker': 'machine',
#     'counterbalance': 7,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_989': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 3683,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 89,
#     'machine_groundtruth': 'ofa',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0330.jpg',
#     'caption': 'a cat holding a dead bird in its mouth',
#     'response_speaker': 'human',
#     'counterbalance': 7,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_990': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 3684,
#     'human_groundtruth': 'Participant_88',
#     'hit': True,
#     'trial': 90,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0111.jpg',
#     'caption': 'a man riding a skateboard in a skatepark',
#     'response_speaker': 'machine',
#     'counterbalance': 7,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_991': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 2625,
#     'human_groundtruth': 'Participant_67',
#     'hit': True,
#     'trial': 91,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0375.jpg',
#     'caption': 'a person with helmet snowboard through the slope',
#     'response_speaker': 'machine',
#     'counterbalance': 7,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_992': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 3091,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 92,
#     'machine_groundtruth': 'blip',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0153.jpg',
#     'caption': 'a woman sitting in the snow with skis and a drink',
#     'response_speaker': 'human',
#     'counterbalance': 7,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_993': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 2244,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 93,
#     'machine_groundtruth': 'catch',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0302.jpg',
#     'caption': 'carpet carpet carpet carpet carpet carpet carpet',
#     'response_speaker': 'machine',
#     'counterbalance': 7,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_994': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 2663,
#     'human_groundtruth': 'Participant_165',
#     'hit': True,
#     'trial': 94,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0306.jpg',
#     'caption': 'people standing under bright red soft drink signs',
#     'response_speaker': 'machine',
#     'counterbalance': 7,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_995': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 5384,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 95,
#     'machine_groundtruth': 'git',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0353.jpg',
#     'caption': 'a group of people playing an outdoor game',
#     'response_speaker': 'machine',
#     'counterbalance': 7,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_996': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 3516,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 96,
#     'machine_groundtruth': 'ofa',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0356.jpg',
#     'caption': 'a woman walking down a runway in a dress with polka dots',
#     'response_speaker': 'human',
#     'counterbalance': 7,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_997': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 3354,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 97,
#     'machine_groundtruth': 'ofa',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0224.jpg',
#     'caption': 'a woman sitting next to a man on a cell phone',
#     'response_speaker': 'human',
#     'counterbalance': 7,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_998': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 2297,
#     'human_groundtruth': '',
#     'hit': True,
#     'trial': 98,
#     'machine_groundtruth': 'catch',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0115.jpg',
#     'caption': 'sidewalk sidewalk sidewalk sidewalk sidewalk sidewalk sidewalk',
#     'response_speaker': 'machine',
#     'counterbalance': 7,
#     'groundtruth': 'machine',
#     'phase': 'TEST'}},
#   'Trial_999': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 4078,
#     'human_groundtruth': 'Participant_6',
#     'hit': True,
#     'trial': 99,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0102.jpg',
#     'caption': 'a black cat with a pizza box and snacks and a remote control on top of it',
#     'response_speaker': 'human',
#     'counterbalance': 7,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   'Trial_1000': {'workerID': 'A1NKBXOTZAI1YK',
#    'workerData': {'country': 'United States',
#     'age': '36-40',
#     'engagement': '5',
#     'difficulty': '0',
#     'gender': 'male',
#     'education': 'bachelor',
#     'ai-experience': '2',
#     'native': 'yes',
#     'imagetype': 'in-domain'},
#    'trialData': {'response_gender': 'NA',
#     'rt': 4506,
#     'human_groundtruth': 'Participant_30',
#     'hit': True,
#     'trial': 100,
#     'machine_groundtruth': '',
#     'imageID': 'https://xiaoturing.s3.us-east-1.amazonaws.com/caption/imgset/0382.jpg',
#     'caption': 'a bike and a red bag lying on sand',
#     'response_speaker': 'machine',
#     'counterbalance': 7,
#     'groundtruth': 'human',
#     'phase': 'TEST'}},
#   ...}}
